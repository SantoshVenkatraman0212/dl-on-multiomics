# %%
#Checking the mutated genes txt file
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import tensorflow as tf
mutated_genes_df = pd.read_csv(r'/home/sanven0212/PycharmProjects/MultiOmicsFYP/Mutated_Genes (3).txt', sep = '\t', skip_blank_lines = True, engine = 'python')
mutated_genes_df.dropna(how = 'all', inplace = True)
# Out:
# 2024-10-02 15:05:34.713306: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-02 15:05:34.733633: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-02 15:05:34.733649: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-02 15:05:34.733663: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-02 15:05:34.737661: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-02 15:05:35.293609: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
mutated_genes_df
# Out:
#          Gene  MutSig(Q-value)  # Mut  #Profiled Samples  Freq  \
# PGLYRP3   NaN                1      1                499  0.2%
# PGLYRP2   NaN                3      3                499  0.6%
# TFRC      NaN                1      1                499  0.2%
# HTR4      NaN                1      1                499  0.2%
# PTPDC1    NaN                1      1                499  0.2%
# ...       ...              ...    ...                ...   ...
# SPRY3     NaN                1      1                499  0.2%
# ARB2A     NaN                1      1                499  0.2%
# ABCE1     NaN                1      1                499  0.2%
# HCN2      NaN                1      1                499  0.2%
# HCN1      NaN                6      6                499  1.2%
#
#         Is Cancer Gene (source: OncoKB)
# PGLYRP3                              No
# PGLYRP2                              No
# TFRC                                Yes
# HTR4                                 No
# PTPDC1                               No
# ...                                 ...
# SPRY3                                No
# ARB2A                                No
# ABCE1                                No
# HCN2                                 No
# HCN1                                 No
#
# [11290 rows x 6 columns]

# %%
#There are a lot of inconsistencies in the .txtfile which have to be handled
with open('/home/sanven0212/PycharmProjects/MultiOmicsFYP/Mutated_Genes (3).txt', 'r') as f:
    lines_of_file = f.readlines()

processed_lines = [lines.strip().split('\t') for lines in lines_of_file]

# %%
processed_lines[0]
# Out:
# ['Gene',
#  'MutSig(Q-value)',
#  '# Mut',
#  '#Profiled Samples',
#  'Freq',
#  'Is Cancer Gene (source: OncoKB)']

# %%
processed_lines[1]
# Out:
# ['PGLYRP3', '', '1', '1', '499', '0.2%', 'No']

# %%
#Now removing all NaN elements
processed_lines = [[i for i in j if i.strip() != '']for j in processed_lines]

# %%
processed_lines
# Out:
# [['Gene',
#   'MutSig(Q-value)',
#   '# Mut',
#   '#Profiled Samples',
#   'Freq',
#   'Is Cancer Gene (source: OncoKB)'],
#  ['PGLYRP3', '1', '1', '499', '0.2%', 'No'],
#  ['PGLYRP2', '3', '3', '499', '0.6%', 'No'],
#  ['TFRC', '1', '1', '499', '0.2%', 'Yes'],
#  ['HTR4', '1', '1', '499', '0.2%', 'No'],
#  ['PTPDC1', '1', '1', '499', '0.2%', 'No'],
#  ['CRHBP', '2', '2', '499', '0.4%', 'No'],
#  ['HTR6', '2', '2', '499', '0.4%', 'No'],
#  ['CAPNS1', '2', '2', '499', '0.4%', 'No'],
#  ['SCP2', '3', '2', '499', '0.4%', 'No'],
#  ['LURAP1L', '3', '3', '499', '0.6%', 'No'],
#  ['BBX', '2', '2', '499', '0.4%', 'No'],
#  ['PRKACA', '2', '2', '499', '0.4%', 'Yes'],
#  ['SPATA31G1', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF17', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF18', '3', '2', '499', '0.4%', 'No'],
#  ['ZNF19', '2', '2', '499', '0.4%', 'No'],
#  ['SDS', '1', '1', '499', '0.2%', 'No'],
#  ['UNC5A', '1', '1', '499', '0.2%', 'No'],
#  ['UNC5B', '5', '5', '499', '1.0%', 'No'],
#  ['SECISBP2', '1', '1', '499', '0.2%', 'No'],
#  ['RC3H1', '2', '2', '499', '0.4%', 'No'],
#  ['INSYN1', '1', '1', '499', '0.2%', 'No'],
#  ['UNC5D', '3', '3', '499', '0.6%', 'No'],
#  ['ZNF14', '1', '1', '499', '0.2%', 'No'],
#  ['RC3H2', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF16', '1', '1', '499', '0.2%', 'No'],
#  ['BCR', '2', '2', '499', '0.4%', 'Yes'],
#  ['LARS2', '2', '2', '499', '0.4%', 'No'],
#  ['SCO1', '1', '1', '499', '0.2%', 'No'],
#  ['TFR2', '1', '1', '499', '0.2%', 'No'],
#  ['LARS1', '3', '3', '499', '0.6%', 'No'],
#  ['DDIT4', '2', '2', '499', '0.4%', 'No'],
#  ['ORAI3', '1', '1', '499', '0.2%', 'No'],
#  ['AGTR1', '3', '3', '499', '0.6%', 'No'],
#  ['HOATZ', '1', '1', '499', '0.2%', 'No'],
#  ['SPATA31H1', '4', '4', '499', '0.8%', 'No'],
#  ['SF1', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF28', '3', '3', '499', '0.6%', 'No'],
#  ['UNC119B', '1', '1', '499', '0.2%', 'No'],
#  ['COL13A1', '1', '1', '499', '0.2%', 'No'],
#  ['SHMT2', '1', '1', '499', '0.2%', 'No'],
#  ['AASDH', '2', '2', '499', '0.4%', 'No'],
#  ['SHMT1', '1', '1', '499', '0.2%', 'No'],
#  ['NPRL3', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF20', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF23', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF24', '1', '1', '499', '0.2%', 'Yes'],
#  ['ADAMTS12', '3', '3', '499', '0.6%', 'No'],
#  ['ADAMTS10', '5', '3', '499', '0.6%', 'No'],
#  ['ADAMTS16', '6', '5', '499', '1.0%', 'No'],
#  ['ADAMTS15', '2', '2', '499', '0.4%', 'No'],
#  ['ADAMTS14', '3', '3', '499', '0.6%', 'No'],
#  ['ADAMTS13', '4', '4', '499', '0.8%', 'No'],
#  ['LARP1', '7', '6', '499', '1.2%', 'No'],
#  ['RDH12', '1', '1', '499', '0.2%', 'No'],
#  ['ADAMTS19', '5', '5', '499', '1.0%', 'No'],
#  ['RDH10', '1', '1', '499', '0.2%', 'No'],
#  ['ADAMTS18', '3', '3', '499', '0.6%', 'No'],
#  ['ADAMTS17', '3', '2', '499', '0.4%', 'No'],
#  ['RDH16', '1', '1', '499', '0.2%', 'No'],
#  ['GSTM3', '1', '1', '499', '0.2%', 'No'],
#  ['GSTM2', '2', '2', '499', '0.4%', 'No'],
#  ['PRPF38B', '2', '2', '499', '0.4%', 'No'],
#  ['NEBL', '4', '3', '499', '0.6%', 'No'],
#  ['ZNF34', '1', '1', '499', '0.2%', 'No'],
#  ['L1CAM', '7', '7', '499', '1.4%', 'No'],
#  ['ZNF35', '2', '2', '499', '0.4%', 'No'],
#  ['LARP4', '3', '3', '499', '0.6%', 'No'],
#  ['DHFR', '2', '2', '499', '0.4%', 'No'],
#  ['MOV10', '3', '3', '499', '0.6%', 'No'],
#  ['PPFIBP1', '5', '4', '499', '0.8%', 'Yes'],
#  ['PPFIBP2', '5', '3', '499', '0.6%', 'No'],
#  ['FXYD3', '1', '1', '499', '0.2%', 'No'],
#  ['STRC', '5', '5', '499', '1.0%', 'No'],
#  ['ZNF30', '3', '2', '499', '0.4%', 'No'],
#  ['STRN', '2', '1', '499', '0.2%', 'Yes'],
#  ['L1TD1', '1', '1', '499', '0.2%', 'No'],
#  ['DZIP3', '2', '2', '499', '0.4%', 'No'],
#  ['GSTM5', '1', '1', '499', '0.2%', 'No'],
#  ['KCNC1', '3', '3', '499', '0.6%', 'No'],
#  ['KCNC3', '1', '1', '499', '0.2%', 'No'],
#  ['KCNC4', '3', '3', '499', '0.6%', 'No'],
#  ['PRKAG1', '3', '3', '499', '0.6%', 'No'],
#  ['ZNF43', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF44', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF45', '1', '1', '499', '0.2%', 'No'],
#  ['FRG2B', '1', '1', '499', '0.2%', 'No'],
#  ['PRKAG3', '1', '1', '499', '0.2%', 'No'],
#  ['SHD', '1', '1', '499', '0.2%', 'No'],
#  ['MMP21', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF48', '3', '3', '499', '0.6%', 'No'],
#  ['MMP20', '1', '1', '499', '0.2%', 'No'],
#  ['NPAP1', '4', '4', '499', '0.8%', 'No'],
#  ['M1AP', '1', '1', '499', '0.2%', 'No'],
#  ['SHE', '2', '2', '499', '0.4%', 'No'],
#  ['SHH', '2', '2', '499', '0.4%', 'No'],
#  ['MMP25', '1', '1', '499', '0.2%', 'No'],
#  ['MMP24', '1', '1', '499', '0.2%', 'No'],
#  ['MMP26', '3', '3', '499', '0.6%', 'No'],
#  ['ZNF41', '1', '1', '499', '0.2%', 'No'],
#  ['NEFM', '2', '2', '499', '0.4%', 'No'],
#  ['STUM', '1', '1', '499', '0.2%', 'No'],
#  ['MYBPC3', '3', '3', '499', '0.6%', 'No'],
#  ['APC2', '3', '2', '499', '0.4%', 'No'],
#  ['MYBPC1', '2', '2', '499', '0.4%', 'No'],
#  ['MYBPC2', '5', '5', '499', '1.0%', 'No'],
#  ['KCND2', '2', '2', '499', '0.4%', 'No'],
#  ['GSTO2', '1', '1', '499', '0.2%', 'No'],
#  ['KCND3', '4', '4', '499', '0.8%', 'No'],
#  ['GSTO1', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF57', '2', '1', '499', '0.2%', 'No'],
#  ['MMP12', '1', '1', '499', '0.2%', 'No'],
#  ['MMP11', '2', '2', '499', '0.4%', 'No'],
#  ['MMP14', '1', '1', '499', '0.2%', 'No'],
#  ['MMP13', '1', '1', '499', '0.2%', 'No'],
#  ['MMP16', '2', '2', '499', '0.4%', 'No'],
#  ['PTRH2', '1', '1', '499', '0.2%', 'No'],
#  ['MMP17', '2', '2', '499', '0.4%', 'No'],
#  ['RAPGEF1', '4', '4', '499', '0.8%', 'No'],
#  ['MMP19', '2', '2', '499', '0.4%', 'No'],
#  ['RAPGEF2', '2', '2', '499', '0.4%', 'No'],
#  ['CRYAA', '1', '1', '499', '0.2%', 'No'],
#  ['RAPGEF6', '5', '5', '499', '1.0%', 'No'],
#  ['RAPGEF3', '1', '1', '499', '0.2%', 'No'],
#  ['RAPGEF4', '3', '3', '499', '0.6%', 'No'],
#  ['TRUB1', '2', '2', '499', '0.4%', 'No'],
#  ['TRUB2', '2', '2', '499', '0.4%', 'No'],
#  ['PKN3', '2', '1', '499', '0.2%', 'No'],
#  ['GSTP1', '1', '1', '499', '0.2%', 'No'],
#  ['KCNA1', '1', '1', '499', '0.2%', 'No'],
#  ['SYNPO2', '2', '2', '499', '0.4%', 'No'],
#  ['KCNA2', '1', '1', '499', '0.2%', 'No'],
#  ['KCNA3', '6', '5', '499', '1.0%', 'No'],
#  ['ADAM22', '1', '1', '499', '0.2%', 'No'],
#  ['KCNA4', '2', '2', '499', '0.4%', 'No'],
#  ['ADAM21', '1', '1', '499', '0.2%', 'No'],
#  ['KCNA5', '3', '3', '499', '0.6%', 'No'],
#  ['ADAM20', '4', '3', '499', '0.6%', 'No'],
#  ['KCNA6', '2', '2', '499', '0.4%', 'No'],
#  ['KCNA7', '2', '2', '499', '0.4%', 'No'],
#  ['SDAD1', '1', '1', '499', '0.2%', 'No'],
#  ['ADAM29', '8', '8', '499', '1.6%', 'No'],
#  ['ADAM28', '3', '3', '499', '0.6%', 'No'],
#  ['ADAM23', '5', '5', '499', '1.0%', 'No'],
#  ['PLAGL2', '1', '1', '499', '0.2%', 'No'],
#  ['RICTOR', '1', '1', '499', '0.2%', 'Yes'],
#  ['SPDEF', '1', '1', '499', '0.2%', 'No'],
#  ['MBD3', '2', '2', '499', '0.4%', 'No'],
#  ['MBD4', '2', '2', '499', '0.4%', 'Yes'],
#  ['MBD5', '1', '1', '499', '0.2%', 'No'],
#  ['MBD6', '2', '2', '499', '0.4%', 'Yes'],
#  ['PKLR', '1', '1', '499', '0.2%', 'No'],
#  ['BIK', '1', '1', '499', '0.2%', 'No'],
#  ['KCNB1', '5', '5', '499', '1.0%', 'No'],
#  ['MBD1', '3', '3', '499', '0.6%', 'No'],
#  ['KCNB2', '7', '7', '499', '1.4%', 'No'],
#  ['SCTR', '3', '3', '499', '0.6%', 'No'],
#  ['BMP8B', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF76', '1', '1', '499', '0.2%', 'No'],
#  ['BBOX1', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF77', '1', '1', '499', '0.2%', 'No'],
#  ['ADAM30', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF79', '1', '1', '499', '0.2%', 'No'],
#  ['TARBP2', '1', '1', '499', '0.2%', 'No'],
#  ['ARCN1', '1', '1', '499', '0.2%', 'No'],
#  ['TARBP1', '4', '3', '499', '0.6%', 'No'],
#  ['ZNF71', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF74', '2', '1', '499', '0.2%', 'No'],
#  ['PKN2', '4', '3', '499', '0.6%', 'No'],
#  ['PKN1', '3', '3', '499', '0.6%', 'No'],
#  ['KCNG1', '2', '2', '499', '0.4%', 'No'],
#  ['KCNG2', '3', '3', '499', '0.6%', 'No'],
#  ['MTCH2', '1', '1', '499', '0.2%', 'No'],
#  ['KCNG4', '3', '2', '499', '0.4%', 'No'],
#  ['RASL11B', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO27', '1', '1', '499', '0.2%', 'No'],
#  ['PDCD5', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO28', '1', '1', '499', '0.2%', 'No'],
#  ['GOLIM4', '3', '3', '499', '0.6%', 'No'],
#  ['IL1RAP', '2', '2', '499', '0.4%', 'No'],
#  ['MSI2', '1', '1', '499', '0.2%', 'Yes'],
#  ['APEH', '2', '2', '499', '0.4%', 'No'],
#  ['FBXO21', '2', '2', '499', '0.4%', 'No'],
#  ['FADS3', '2', '2', '499', '0.4%', 'No'],
#  ['POTEM', '7', '7', '499', '1.4%', 'No'],
#  ['SLK', '2', '2', '499', '0.4%', 'No'],
#  ['FNTA', '1', '1', '499', '0.2%', 'No'],
#  ['POTEH', '4', '3', '499', '0.6%', 'No'],
#  ['MYBPHL', '2', '2', '499', '0.4%', 'No'],
#  ['POFUT1', '1', '1', '499', '0.2%', 'No'],
#  ['FNTB', '1', '1', '499', '0.2%', 'No'],
#  ['NFATC2IP', '1', '1', '499', '0.2%', 'No'],
#  ['POTED', '1', '1', '499', '0.2%', 'No'],
#  ['TNFRSF8', '3', '3', '499', '0.6%', 'No'],
#  ['NEK1', '3', '3', '499', '0.6%', 'No'],
#  ['POTEE', '3', '3', '499', '0.6%', 'No'],
#  ['MAP3K8', '1', '1', '499', '0.2%', 'No'],
#  ['POTEF', '4', '4', '499', '0.8%', 'No'],
#  ['MAP3K9', '12', '11', '499', '2.2%', 'No'],
#  ['POTEG', '2', '2', '499', '0.4%', 'No'],
#  ['MAP3K7', '2', '2', '499', '0.4%', 'Yes'],
#  ['TNFRSF4', '2', '2', '499', '0.4%', 'No'],
#  ['MAP3K4', '3', '2', '499', '0.4%', 'No'],
#  ['KCNH1', '2', '2', '499', '0.4%', 'No'],
#  ['MAP3K5', '2', '2', '499', '0.4%', 'No'],
#  ['POTEC', '13', '13', '499', '2.6%', 'No'],
#  ['KCNH2', '2', '2', '499', '0.4%', 'No'],
#  ['PIAS4', '3', '2', '499', '0.4%', 'No'],
#  ['PIAS3', '2', '2', '499', '0.4%', 'No'],
#  ['KCNH3', '1', '1', '499', '0.2%', 'No'],
#  ['KCNH4', '3', '3', '499', '0.6%', 'No'],
#  ['KCNH5', '5', '5', '499', '1.0%', 'No'],
#  ['DGAT2', '1', '1', '499', '0.2%', 'No'],
#  ['DGAT1', '1', '1', '499', '0.2%', 'No'],
#  ['FBXW8', '1', '1', '499', '0.2%', 'No'],
#  ['KCNH6', '2', '2', '499', '0.4%', 'No'],
#  ['KCNH7', '6', '6', '499', '1.2%', 'No'],
#  ['STX8', '2', '1', '499', '0.2%', 'No'],
#  ['KCNH8', '3', '3', '499', '0.6%', 'No'],
#  ['FBXO16', '2', '2', '499', '0.4%', 'No'],
#  ['STX7', '1', '1', '499', '0.2%', 'No'],
#  ['FBXW9', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO10', '2', '2', '499', '0.4%', 'No'],
#  ['SRCIN1', '1', '1', '499', '0.2%', 'No'],
#  ['MSH6', '3', '3', '499', '0.6%', 'Yes'],
#  ['NPAS4', '2', '2', '499', '0.4%', 'No'],
#  ['MSH2', '2', '2', '499', '0.4%', 'Yes'],
#  ['DMTF1', '4', '4', '499', '0.8%', 'No'],
#  ['MSH3', '9', '8', '499', '1.6%', 'Yes'],
#  ['MSH4', '2', '2', '499', '0.4%', 'No'],
#  ['MSH5', '1', '1', '499', '0.2%', 'No'],
#  ['PKP2', '2', '2', '499', '0.4%', 'No'],
#  ['PKP1', '2', '1', '499', '0.2%', 'No'],
#  ['PKP4', '1', '1', '499', '0.2%', 'No'],
#  ['BLK', '1', '1', '499', '0.2%', 'No'],
#  ['KCNE2', '1', '1', '499', '0.2%', 'No'],
#  ['KCNE3', '2', '2', '499', '0.4%', 'No'],
#  ['IREB2', '4', '4', '499', '0.8%', 'No'],
#  ['FBXO45', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO46', '3', '3', '499', '0.6%', 'No'],
#  ['FBXO43', '2', '2', '499', '0.4%', 'No'],
#  ['CES5A', '1', '1', '499', '0.2%', 'No'],
#  ['NPAS2', '1', '1', '499', '0.2%', 'No'],
#  ['CCDC144A', '3', '3', '499', '0.6%', 'No'],
#  ['FBXO42', '5', '4', '499', '0.8%', 'No'],
#  ['FBXO40', '1', '1', '499', '0.2%', 'No'],
#  ['RAP1A', '1', '1', '499', '0.2%', 'No'],
#  ['NDOR1', '1', '1', '499', '0.2%', 'No'],
#  ['ZKSCAN7', '1', '1', '499', '0.2%', 'No'],
#  ['ZKSCAN8', '1', '1', '499', '0.2%', 'No'],
#  ['MBIP', '1', '1', '499', '0.2%', 'No'],
#  ['ZKSCAN2', '1', '1', '499', '0.2%', 'No'],
#  ['ZKSCAN5', '3', '3', '499', '0.6%', 'No'],
#  ['CERT1', '3', '3', '499', '0.6%', 'No'],
#  ['ZKSCAN1', '2', '2', '499', '0.4%', 'No'],
#  ['NEK8', '1', '1', '499', '0.2%', 'No'],
#  ['KCNF1', '1', '1', '499', '0.2%', 'No'],
#  ['NOP14', '1', '1', '499', '0.2%', 'No'],
#  ['SDF2L1', '2', '2', '499', '0.4%', 'No'],
#  ['HTR1E', '6', '6', '499', '1.2%', 'No'],
#  ['NEK4', '3', '2', '499', '0.4%', 'No'],
#  ['RASL10A', '1', '1', '499', '0.2%', 'No'],
#  ['NOP16', '1', '1', '499', '0.2%', 'No'],
#  ['API5', '1', '1', '499', '0.2%', 'No'],
#  ['NEK6', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO38', '4', '4', '499', '0.8%', 'No'],
#  ['HTR1D', '2', '2', '499', '0.4%', 'No'],
#  ['FBXO39', '2', '2', '499', '0.4%', 'No'],
#  ['HTR1A', '3', '3', '499', '0.6%', 'No'],
#  ['FBXO36', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO34', '3', '3', '499', '0.6%', 'No'],
#  ['BMX', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO32', '1', '1', '499', '0.2%', 'No'],
#  ['G6PC1', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO30', '1', '1', '499', '0.2%', 'No'],
#  ['FAM90A1', '2', '2', '499', '0.4%', 'No'],
#  ['G6PC2', '1', '1', '499', '0.2%', 'No'],
#  ['SON', '3', '3', '499', '0.6%', 'No'],
#  ['LRCH1', '4', '4', '499', '0.8%', 'No'],
#  ['G6PC3', '2', '2', '499', '0.4%', 'No'],
#  ['SP2', '1', '1', '499', '0.2%', 'No'],
#  ['SP1', '2', '2', '499', '0.4%', 'No'],
#  ['SP4', '6', '5', '499', '1.0%', 'No'],
#  ['SP3', '3', '3', '499', '0.6%', 'No'],
#  ['SP8', '5', '5', '499', '1.0%', 'No'],
#  ['LRCH4', '1', '1', '499', '0.2%', 'No'],
#  ['SLC49A4', '4', '3', '499', '0.6%', 'No'],
#  ['SLC49A3', '1', '1', '499', '0.2%', 'No'],
#  ['BCAR3', '3', '3', '499', '0.6%', 'No'],
#  ['KCNK5', '3', '3', '499', '0.6%', 'No'],
#  ['PIWIL2', '4', '3', '499', '0.6%', 'No'],
#  ['PIWIL1', '7', '6', '499', '1.2%', 'No'],
#  ['KCNK6', '1', '1', '499', '0.2%', 'No'],
#  ['ALAS2', '1', '1', '499', '0.2%', 'No'],
#  ['KCNK7', '1', '1', '499', '0.2%', 'No'],
#  ['BMP10', '1', '1', '499', '0.2%', 'No'],
#  ['ALAS1', '3', '2', '499', '0.4%', 'No'],
#  ['PIWIL3', '2', '2', '499', '0.4%', 'No'],
#  ['ONECUT2', '3', '3', '499', '0.6%', 'Yes'],
#  ['KCNK9', '2', '2', '499', '0.4%', 'No'],
#  ['MTCL1', '6', '6', '499', '1.2%', 'No'],
#  ['MTCL2', '3', '3', '499', '0.6%', 'No'],
#  ['ONECUT1', '2', '2', '499', '0.4%', 'No'],
#  ['MTCL3', '4', '2', '499', '0.4%', 'No'],
#  ['HTR2B', '2', '2', '499', '0.4%', 'No'],
#  ['DYSF', '4', '2', '499', '0.4%', 'No'],
#  ['HTR2C', '3', '3', '499', '0.6%', 'No'],
#  ['PPWD1', '1', '1', '499', '0.2%', 'No'],
#  ['HTR2A', '2', '2', '499', '0.4%', 'No'],
#  ['MSLN', '2', '2', '499', '0.4%', 'No'],
#  ['BICD1', '3', '3', '499', '0.6%', 'No'],
#  ['BICD2', '4', '3', '499', '0.6%', 'No'],
#  ['BMP15', '1', '1', '499', '0.2%', 'No'],
#  ['SPN', '1', '1', '499', '0.2%', 'No'],
#  ['UNC80', '3', '3', '499', '0.6%', 'No'],
#  ['SPR', '1', '1', '499', '0.2%', 'No'],
#  ['OR56B1', '1', '1', '499', '0.2%', 'No'],
#  ['SPDL1', '2', '2', '499', '0.4%', 'No'],
#  ['NEO1', '4', '3', '499', '0.6%', 'No'],
#  ['BCAS2', '1', '1', '499', '0.2%', 'No'],
#  ['BCAS1', '1', '1', '499', '0.2%', 'No'],
#  ['BCAS4', '1', '1', '499', '0.2%', 'No'],
#  ['UNC45A', '1', '1', '499', '0.2%', 'No'],
#  ['CERS3', '1', '1', '499', '0.2%', 'No'],
#  ['SLC36A1', '1', '1', '499', '0.2%', 'No'],
#  ['CERS4', '1', '1', '499', '0.2%', 'No'],
#  ['UNC45B', '2', '2', '499', '0.4%', 'No'],
#  ['CERS5', '1', '1', '499', '0.2%', 'No'],
#  ['SLC36A3', '1', '1', '499', '0.2%', 'No'],
#  ['SLC36A2', '3', '2', '499', '0.4%', 'No'],
#  ['CERS6', '1', '1', '499', '0.2%', 'No'],
#  ['RNASET2', '1', '1', '499', '0.2%', 'No'],
#  ['VPS13C', '7', '7', '499', '1.4%', 'No'],
#  ['DHPS', '1', '1', '499', '0.2%', 'No'],
#  ['VPS13D', '13', '8', '499', '1.6%', 'No'],
#  ['VPS13A', '4', '3', '499', '0.6%', 'No'],
#  ['MSL2', '1', '1', '499', '0.2%', 'No'],
#  ['HTR3C', '1', '1', '499', '0.2%', 'No'],
#  ['VPS13B', '11', '8', '499', '1.6%', 'No'],
#  ['HTR3B', '1', '1', '499', '0.2%', 'No'],
#  ['RABGGTA', '1', '1', '499', '0.2%', 'No'],
#  ['CES4A', '3', '3', '499', '0.6%', 'No'],
#  ['ADAMTS20', '8', '7', '499', '1.4%', 'No'],
#  ['MSL1', '1', '1', '499', '0.2%', 'No'],
#  ['NEMF', '2', '2', '499', '0.4%', 'No'],
#  ['BMP2K', '7', '7', '499', '1.4%', 'No'],
#  ['BPI', '2', '2', '499', '0.4%', 'No'],
#  ['BCAT1', '1', '1', '499', '0.2%', 'No'],
#  ['OR56A4', '1', '1', '499', '0.2%', 'No'],
#  ['GAPDH', '1', '1', '499', '0.2%', 'No'],
#  ['OR56A3', '3', '3', '499', '0.6%', 'No'],
#  ['BCAT2', '2', '1', '499', '0.2%', 'No'],
#  ['CERS2', '2', '2', '499', '0.4%', 'No'],
#  ['OR56A1', '2', '2', '499', '0.4%', 'No'],
#  ['BLTP3A', '5', '5', '499', '1.0%', 'No'],
#  ['PRKAA2', '5', '5', '499', '1.0%', 'No'],
#  ['BLTP3B', '3', '2', '499', '0.4%', 'No'],
#  ['C1S', '4', '4', '499', '0.8%', 'No'],
#  ['UHRF2', '1', '1', '499', '0.2%', 'No'],
#  ['LENG8', '5', '2', '499', '0.4%', 'No'],
#  ['MLLT1', '2', '2', '499', '0.4%', 'Yes'],
#  ['U2AF1', '1', '1', '499', '0.2%', 'Yes'],
#  ['SRI', '2', '2', '499', '0.4%', 'No'],
#  ['MLLT3', '2', '2', '499', '0.4%', 'Yes'],
#  ['MLLT6', '3', '2', '499', '0.4%', 'Yes'],
#  ['SRM', '1', '1', '499', '0.2%', 'No'],
#  ['AWAT1', '1', '1', '499', '0.2%', 'No'],
#  ['U2AF2', '1', '1', '499', '0.2%', 'Yes'],
#  ['AWAT2', '1', '1', '499', '0.2%', 'No'],
#  ['KRIT1', '3', '3', '499', '0.6%', 'No'],
#  ['TSPOAP1', '5', '3', '499', '0.6%', 'No'],
#  ['BBLN', '1', '1', '499', '0.2%', 'No'],
#  ['KCNJ2', '2', '2', '499', '0.4%', 'No'],
#  ['KCNJ4', '3', '3', '499', '0.6%', 'No'],
#  ['NOP56', '1', '1', '499', '0.2%', 'No'],
#  ['KCNJ5', '2', '2', '499', '0.4%', 'Yes'],
#  ['KCNJ6', '2', '2', '499', '0.4%', 'No'],
#  ['NOP58', '2', '2', '499', '0.4%', 'No'],
#  ['COL26A1', '3', '3', '499', '0.6%', 'No'],
#  ['SSB', '4', '4', '499', '0.8%', 'No'],
#  ['KCNJ8', '1', '1', '499', '0.2%', 'No'],
#  ['GPKOW', '2', '2', '499', '0.4%', 'No'],
#  ['HTR5A', '1', '1', '499', '0.2%', 'No'],
#  ['SORL1', '3', '3', '499', '0.6%', 'No'],
#  ['MSMP', '1', '1', '499', '0.2%', 'No'],
#  ['DYTN', '2', '2', '499', '0.4%', 'No'],
#  ['CDKN2AIPNL', '1', '1', '499', '0.2%', 'No'],
#  ['UROC1', '3', '3', '499', '0.6%', 'No'],
#  ['IL2RB', '1', '1', '499', '0.2%', 'No'],
#  ['APLF', '1', '1', '499', '0.2%', 'No'],
#  ['PDCD2', '1', '1', '499', '0.2%', 'No'],
#  ['PDCD1', '1', '1', '499', '0.2%', 'Yes'],
#  ['KCNK1', '1', '1', '499', '0.2%', 'No'],
#  ['KCNK2', '3', '3', '499', '0.6%', 'No'],
#  ['NOP53', '1', '1', '499', '0.2%', 'No'],
#  ['BCAR1', '3', '2', '499', '0.4%', 'No'],
#  ['UNC79', '9', '9', '499', '1.8%', 'No'],
#  ['CDRT15', '1', '1', '499', '0.2%', 'No'],
#  ['SLC23A2', '1', '1', '499', '0.2%', 'No'],
#  ['CERK', '1', '1', '499', '0.2%', 'No'],
#  ['RCBTB2', '1', '1', '499', '0.2%', 'No'],
#  ['STS', '1', '1', '499', '0.2%', 'No'],
#  ['IL36A', '1', '1', '499', '0.2%', 'No'],
#  ['IL36B', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO4', '2', '2', '499', '0.4%', 'No'],
#  ['TNFSF11', '1', '1', '499', '0.2%', 'No'],
#  ['BCRP7', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO6', '2', '2', '499', '0.4%', 'No'],
#  ['FBXO5', '2', '2', '499', '0.4%', 'No'],
#  ['BSN', '11', '10', '499', '2.0%', 'No'],
#  ['ATXN7L2', '1', '1', '499', '0.2%', 'No'],
#  ['ATXN7L3', '1', '1', '499', '0.2%', 'No'],
#  ['LIMCH1', '4', '4', '499', '0.8%', 'No'],
#  ['BSX', '1', '1', '499', '0.2%', 'No'],
#  ['GOLPH3L', '2', '2', '499', '0.4%', 'No'],
#  ['BCS1L', '2', '2', '499', '0.4%', 'No'],
#  ['CFAP141', '1', '1', '499', '0.2%', 'No'],
#  ['BTD', '1', '1', '499', '0.2%', 'No'],
#  ['SNORC', '1', '1', '499', '0.2%', 'No'],
#  ['CRISPLD1', '1', '1', '499', '0.2%', 'No'],
#  ['SOAT2', '3', '3', '499', '0.6%', 'No'],
#  ['KCNQ1', '2', '2', '499', '0.4%', 'No'],
#  ['KCNQ2', '2', '2', '499', '0.4%', 'No'],
#  ['BTK', '1', '1', '499', '0.2%', 'Yes'],
#  ['KCNQ3', '3', '3', '499', '0.6%', 'No'],
#  ['MTCP1', '1', '1', '499', '0.2%', 'Yes'],
#  ['KCNQ5', '2', '2', '499', '0.4%', 'No'],
#  ['CES3', '1', '1', '499', '0.2%', 'No'],
#  ['CES2', '2', '1', '499', '0.2%', 'No'],
#  ['CES1', '3', '3', '499', '0.6%', 'No'],
#  ['CETP', '2', '2', '499', '0.4%', 'No'],
#  ['GRB7', '2', '2', '499', '0.4%', 'Yes'],
#  ['CERKL', '1', '1', '499', '0.2%', 'No'],
#  ['AARS1', '2', '2', '499', '0.4%', 'No'],
#  ['AARS2', '2', '1', '499', '0.2%', 'No'],
#  ['DHX8', '2', '2', '499', '0.4%', 'No'],
#  ['SDC4', '1', '1', '499', '0.2%', 'Yes'],
#  ['DHX9', '1', '1', '499', '0.2%', 'No'],
#  ['RRAD', '1', '1', '499', '0.2%', 'No'],
#  ['SDC3', '1', '1', '499', '0.2%', 'No'],
#  ['MYCBP2', '10', '9', '499', '1.8%', 'No'],
#  ['CWF19L2', '2', '2', '499', '0.4%', 'No'],
#  ['ZBTB5', '1', '1', '499', '0.2%', 'No'],
#  ['ZBTB4', '2', '2', '499', '0.4%', 'No'],
#  ['ZBTB3', '2', '2', '499', '0.4%', 'No'],
#  ['CFAP126', '1', '1', '499', '0.2%', 'No'],
#  ['ZBTB2', '1', '1', '499', '0.2%', 'No'],
#  ['NEU2', '2', '2', '499', '0.4%', 'No'],
#  ['PKHD1', '10', '9', '499', '1.8%', 'No'],
#  ['APOO', '2', '2', '499', '0.4%', 'No'],
#  ['NEU4', '2', '2', '499', '0.4%', 'No'],
#  ['MRNIP', '3', '3', '499', '0.6%', 'No'],
#  ['NKAIN3', '1', '1', '499', '0.2%', 'No'],
#  ['RACGAP1', '1', '1', '499', '0.2%', 'No'],
#  ['NEU1', '1', '1', '499', '0.2%', 'No'],
#  ['KCNN1', '1', '1', '499', '0.2%', 'No'],
#  ['STK38L', '1', '1', '499', '0.2%', 'No'],
#  ['KCNN2', '6', '6', '499', '1.2%', 'No'],
#  ['H3C3', '1', '1', '499', '0.2%', 'Yes'],
#  ['APOE', '2', '2', '499', '0.4%', 'No'],
#  ['KCNN3', '3', '3', '499', '0.6%', 'No'],
#  ['H3C2', '1', '1', '499', '0.2%', 'Yes'],
#  ['APOB', '11', '10', '499', '2.0%', 'No'],
#  ['KCNN4', '1', '1', '499', '0.2%', 'No'],
#  ['H3C7', '1', '1', '499', '0.2%', 'Yes'],
#  ['H3C6', '1', '1', '499', '0.2%', 'Yes'],
#  ['BBS2', '2', '2', '499', '0.4%', 'No'],
#  ['NTNG1', '3', '3', '499', '0.6%', 'No'],
#  ['BBS1', '2', '2', '499', '0.4%', 'No'],
#  ['NTNG2', '1', '1', '499', '0.2%', 'No'],
#  ['SLC10A5', '1', '1', '499', '0.2%', 'No'],
#  ['XBP1', '1', '1', '499', '0.2%', 'Yes'],
#  ['YES1', '1', '1', '499', '0.2%', 'Yes'],
#  ['TNFSF14', '2', '2', '499', '0.4%', 'No'],
#  ['APOBEC3G', '1', '1', '499', '0.2%', 'No'],
#  ['TNFSF15', '1', '1', '499', '0.2%', 'No'],
#  ['SLC10A2', '5', '5', '499', '1.0%', 'No'],
#  ['SPDYC', '2', '2', '499', '0.4%', 'No'],
#  ['SLC10A3', '1', '1', '499', '0.2%', 'No'],
#  ['IGF2', '1', '1', '499', '0.2%', 'Yes'],
#  ['DELE1', '3', '3', '499', '0.6%', 'No'],
#  ['SUCO', '1', '1', '499', '0.2%', 'No'],
#  ['CPLANE1', '3', '1', '499', '0.2%', 'No'],
#  ['NET1', '3', '3', '499', '0.6%', 'No'],
#  ['ZBTB9', '2', '2', '499', '0.4%', 'No'],
#  ['CYP26A1', '1', '1', '499', '0.2%', 'No'],
#  ['FBXL8', '1', '1', '499', '0.2%', 'No'],
#  ['PEX5L', '1', '1', '499', '0.2%', 'No'],
#  ['ZBTB6', '1', '1', '499', '0.2%', 'No'],
#  ['CWF19L1', '4', '3', '499', '0.6%', 'No'],
#  ['OR4D11', '1', '1', '499', '0.2%', 'No'],
#  ['ITGBL1', '3', '3', '499', '0.6%', 'No'],
#  ['OR4D10', '2', '2', '499', '0.4%', 'No'],
#  ['GRB2', '1', '1', '499', '0.2%', 'No'],
#  ['FBXL2', '1', '1', '499', '0.2%', 'No'],
#  ['FBXL4', '1', '1', '499', '0.2%', 'No'],
#  ['FBXL7', '3', '3', '499', '0.6%', 'No'],
#  ['LDHAL6A', '1', '1', '499', '0.2%', 'No'],
#  ['APOBEC3B', '4', '4', '499', '0.8%', 'Yes'],
#  ['FBXL6', '2', '2', '499', '0.4%', 'No'],
#  ['MSTN', '2', '2', '499', '0.4%', 'No'],
#  ['MRPS10', '2', '2', '499', '0.4%', 'No'],
#  ['C8B', '2', '2', '499', '0.4%', 'No'],
#  ['TFB1M', '1', '1', '499', '0.2%', 'No'],
#  ['C8A', '3', '1', '499', '0.2%', 'No'],
#  ['MC4R', '1', '1', '499', '0.2%', 'No'],
#  ['DMBX1', '2', '2', '499', '0.4%', 'No'],
#  ['KCNT1', '4', '4', '499', '0.8%', 'No'],
#  ['KCNT2', '7', '6', '499', '1.2%', 'No'],
#  ['SUFU', '1', '1', '499', '0.2%', 'Yes'],
#  ['RAC2', '1', '1', '499', '0.2%', 'Yes'],
#  ['FCER1A', '1', '1', '499', '0.2%', 'No'],
#  ['RAC3', '2', '2', '499', '0.4%', 'No'],
#  ['BBS9', '5', '5', '499', '1.0%', 'No'],
#  ['SDF4', '1', '1', '499', '0.2%', 'No'],
#  ['RAC1', '1', '1', '499', '0.2%', 'Yes'],
#  ['BBS7', '1', '1', '499', '0.2%', 'No'],
#  ['BBS5', '1', '1', '499', '0.2%', 'No'],
#  ['BBS4', '4', '4', '499', '0.8%', 'No'],
#  ['MRPS28', '1', '1', '499', '0.2%', 'No'],
#  ['H3C8', '3', '3', '499', '0.6%', 'Yes'],
#  ['PCYT1B', '1', '1', '499', '0.2%', 'No'],
#  ['ZHX2', '3', '2', '499', '0.4%', 'No'],
#  ['PCYT1A', '1', '1', '499', '0.2%', 'No'],
#  ['ZHX3', '1', '1', '499', '0.2%', 'No'],
#  ['SYK', '2', '2', '499', '0.4%', 'Yes'],
#  ['MRPS25', '2', '2', '499', '0.4%', 'No'],
#  ['MRPS22', '1', '1', '499', '0.2%', 'No'],
#  ['MST1', '4', '3', '499', '0.6%', 'Yes'],
#  ['MRPS23', '1', '1', '499', '0.2%', 'No'],
#  ['GAB1', '1', '1', '499', '0.2%', 'Yes'],
#  ['PRPF40B', '3', '3', '499', '0.6%', 'No'],
#  ['CACYBP', '1', '1', '499', '0.2%', 'No'],
#  ['GAB2', '5', '5', '499', '1.0%', 'Yes'],
#  ['TFB2M', '3', '3', '499', '0.6%', 'No'],
#  ['ZHX1', '2', '2', '499', '0.4%', 'No'],
#  ['APRT', '1', '1', '499', '0.2%', 'No'],
#  ['RNF144A', '1', '1', '499', '0.2%', 'No'],
#  ['CNKSR2', '1', '1', '499', '0.2%', 'No'],
#  ['MC3R', '2', '2', '499', '0.4%', 'No'],
#  ['CNKSR1', '1', '1', '499', '0.2%', 'No'],
#  ['KCNU1', '4', '3', '499', '0.6%', 'No'],
#  ['RAP2B', '1', '1', '499', '0.2%', 'No'],
#  ['PITPNM1', '2', '1', '499', '0.2%', 'No'],
#  ['PITPNM2', '1.640e-12', '2', '1', '499', '0.2%', 'No'],
#  ['CNKSR3', '1', '1', '499', '0.2%', 'No'],
#  ['TAX1BP1', '3', '2', '499', '0.4%', 'No'],
#  ['TLCD4', '1', '1', '499', '0.2%', 'No'],
#  ['FAM193B', '1', '1', '499', '0.2%', 'No'],
#  ['FAM193A', '4', '4', '499', '0.8%', 'No'],
#  ['CYLC2', '1', '1', '499', '0.2%', 'No'],
#  ['MICU1', '2', '2', '499', '0.4%', 'No'],
#  ['CYLC1', '1', '1', '499', '0.2%', 'No'],
#  ['DYNC1I2', '1', '1', '499', '0.2%', 'No'],
#  ['SELPLG', '2', '2', '499', '0.4%', 'No'],
#  ['PRICKLE2', '7', '6', '499', '1.2%', 'No'],
#  ['MRPS30', '1', '1', '499', '0.2%', 'No'],
#  ['PRICKLE1', '2', '2', '499', '0.4%', 'No'],
#  ['MSX1', '1', '1', '499', '0.2%', 'No'],
#  ['RAE1', '3', '3', '499', '0.6%', 'No'],
#  ['DYNC1I1', '2', '2', '499', '0.4%', 'No'],
#  ['PEX16', '1', '1', '499', '0.2%', 'No'],
#  ['DYNC1H1', '8', '6', '499', '1.2%', 'No'],
#  ['MAP3K3', '1', '1', '499', '0.2%', 'No'],
#  ['MAP3K1', '5', '3', '499', '0.6%', 'Yes'],
#  ['SORT1', '1', '1', '499', '0.2%', 'No'],
#  ['GAD1', '2', '2', '499', '0.4%', 'No'],
#  ['GAD2', '9', '9', '499', '1.8%', 'No'],
#  ['KLHL2', '3', '3', '499', '0.6%', 'No'],
#  ['KLHL3', '1', '1', '499', '0.2%', 'No'],
#  ['KLHL4', '3', '3', '499', '0.6%', 'No'],
#  ['KCNRG', '1', '1', '499', '0.2%', 'No'],
#  ['PEX12', '1', '1', '499', '0.2%', 'No'],
#  ['CFAP157', '2', '2', '499', '0.4%', 'No'],
#  ['APTX', '1', '1', '499', '0.2%', 'No'],
#  ['KLHL9', '2', '2', '499', '0.4%', 'No'],
#  ['ETAA1', '2', '2', '499', '0.4%', 'Yes'],
#  ['PDCL3', '1', '1', '499', '0.2%', 'No'],
#  ['PDCL2', '1', '1', '499', '0.2%', 'No'],
#  ['TFAP4', '4', '3', '499', '0.6%', 'No'],
#  ['KCNS1', '1', '1', '499', '0.2%', 'No'],
#  ['KLHL5', '1', '1', '499', '0.2%', 'No'],
#  ['FHIP2A', '1', '1', '499', '0.2%', 'No'],
#  ['KCNS2', '1', '1', '499', '0.2%', 'No'],
#  ['FHIP2B', '1', '1', '499', '0.2%', 'No'],
#  ['KLHL6', '2', '2', '499', '0.4%', 'Yes'],
#  ['KCNS3', '1', '1', '499', '0.2%', 'No'],
#  ['KLHL7', '3', '3', '499', '0.6%', 'No'],
#  ['MC5R', '1', '1', '499', '0.2%', 'No'],
#  ['KLHL8', '2', '2', '499', '0.4%', 'No'],
#  ['CFAP161', '1', '1', '499', '0.2%', 'No'],
#  ['TACC3', '3', '2', '499', '0.4%', 'No'],
#  ['CACHD1', '4', '3', '499', '0.6%', 'No'],
#  ['HDGF', '1', '1', '499', '0.2%', 'No'],
#  ['TACC1', '1', '1', '499', '0.2%', 'No'],
#  ['TACC2', '6', '6', '499', '1.2%', 'No'],
#  ['MAMLD1', '1', '1', '499', '0.2%', 'No'],
#  ['ZFP28', '4', '4', '499', '0.8%', 'No'],
#  ['DENND5B', '1', '1', '499', '0.2%', 'No'],
#  ['INPPL1', '1', '1', '499', '0.2%', 'Yes'],
#  ['PLAT', '3', '3', '499', '0.6%', 'No'],
#  ['PLB1', '2', '2', '499', '0.4%', 'No'],
#  ['IGF1R', '4', '4', '499', '0.8%', 'Yes'],
#  ['TXN2', '1', '1', '499', '0.2%', 'No'],
#  ['TGM1', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF81', '1', '1', '499', '0.2%', 'No'],
#  ['DMBT1', '6', '5', '499', '1.0%', 'No'],
#  ['PLAU', '3', '3', '499', '0.6%', 'No'],
#  ['PPIP5K2', '5', '2', '499', '0.4%', 'No'],
#  ['ZNF85', '1', '1', '499', '0.2%', 'No'],
#  ['ENPP2', '4', '4', '499', '0.8%', 'No'],
#  ['ENPP1', '3', '3', '499', '0.6%', 'No'],
#  ['RXYLT1', '2', '2', '499', '0.4%', 'No'],
#  ['ENPP4', '2', '2', '499', '0.4%', 'No'],
#  ['DENND5A', '2', '2', '499', '0.4%', 'No'],
#  ['TGM7', '2', '2', '499', '0.4%', 'No'],
#  ['ENPP3', '2', '2', '499', '0.4%', 'No'],
#  ['TGM6', '5', '5', '499', '1.0%', 'No'],
#  ['TGM5', '2', '2', '499', '0.4%', 'No'],
#  ['ENPP5', '3', '3', '499', '0.6%', 'No'],
#  ['TGM3', '2', '2', '499', '0.4%', 'No'],
#  ['RAG1', '3.530e-2', '11', '10', '499', '2.0%', 'No'],
#  ['TGM2', '2', '1', '499', '0.2%', 'No'],
#  ['ENPP7', '4', '3', '499', '0.6%', 'No'],
#  ['CARD10', '2', '2', '499', '0.4%', 'No'],
#  ['MSX2', '1', '1', '499', '0.2%', 'No'],
#  ['ZGRF1', '1', '1', '499', '0.2%', 'No'],
#  ['ADAM11', '2', '2', '499', '0.4%', 'No'],
#  ['ADAM10', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF98', '2', '2', '499', '0.4%', 'No'],
#  ['DNAJB13', '1', '1', '499', '0.2%', 'No'],
#  ['SDHC', '2', '2', '499', '0.4%', 'Yes'],
#  ['ZNF99', '10', '10', '499', '2.0%', 'No'],
#  ['DNAJB14', '1', '1', '499', '0.2%', 'No'],
#  ['SDHA', '3', '2', '499', '0.4%', 'Yes'],
#  ['SDHB', '2', '2', '499', '0.4%', 'Yes'],
#  ['ADAM19', '2', '2', '499', '0.4%', 'No'],
#  ['ADAM18', '3', '3', '499', '0.6%', 'No'],
#  ['ZNF91', '12', '12', '499', '2.4%', 'No'],
#  ['BRMS1', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF92', '1', '1', '499', '0.2%', 'No'],
#  ['ADAM15', '3', '2', '499', '0.4%', 'No'],
#  ['ZNF93', '2', '2', '499', '0.4%', 'No'],
#  ['PSPC1', '2', '2', '499', '0.4%', 'No'],
#  ['CARD19', '1', '1', '499', '0.2%', 'No'],
#  ['ADAM12', '3', '3', '499', '0.6%', 'No'],
#  ['DNAJB11', '1', '1', '499', '0.2%', 'No'],
#  ['PLAA', '6', '5', '499', '1.0%', 'No'],
#  ['CARD18', '1', '1', '499', '0.2%', 'No'],
#  ['CARD16', '2', '2', '499', '0.4%', 'No'],
#  ['DENND6A', '1', '1', '499', '0.2%', 'No'],
#  ['RAF1', '1', '1', '499', '0.2%', 'Yes'],
#  ['CARD14', '2', '2', '499', '0.4%', 'No'],
#  ['CARD11', '5', '3', '499', '0.6%', 'Yes'],
#  ['OR1A2', '1', '1', '499', '0.2%', 'No'],
#  ['DIPK1B', '1', '1', '499', '0.2%', 'No'],
#  ['HTRA4', '2', '2', '499', '0.4%', 'No'],
#  ['HTRA1', '1', '1', '499', '0.2%', 'No'],
#  ['PLD5', '1', '1', '499', '0.2%', 'No'],
#  ['DAPP1', '1', '1', '499', '0.2%', 'No'],
#  ['HTRA2', '1', '1', '499', '0.2%', 'No'],
#  ['PLD4', '1', '1', '499', '0.2%', 'No'],
#  ['PLD1', '3', '3', '499', '0.6%', 'No'],
#  ['PLD2', '2', '2', '499', '0.4%', 'No'],
#  ['GRK1', '2', '2', '499', '0.4%', 'No'],
#  ['RAI1', '5', '5', '499', '1.0%', 'No'],
#  ['KCNV1', '5', '5', '499', '1.0%', 'No'],
#  ['KCNV2', '2', '1', '499', '0.2%', 'No'],
#  ['GRK4', '1', '1', '499', '0.2%', 'No'],
#  ['GRK7', '1', '1', '499', '0.2%', 'No'],
#  ['GRK6', '3', '3', '499', '0.6%', 'No'],
#  ['FGF20', '1', '1', '499', '0.2%', 'No'],
#  ['IL36RN', '2', '2', '499', '0.4%', 'No'],
#  ['FGF23', '2', '2', '499', '0.4%', 'Yes'],
#  ['PIBF1', '1', '1', '499', '0.2%', 'No'],
#  ['FGF21', '1', '1', '499', '0.2%', 'No'],
#  ['SPATA31A6', '10', '9', '499', '1.8%', 'No'],
#  ['SPATA31A7', '2', '2', '499', '0.4%', 'No'],
#  ['DENND4B', '2', '2', '499', '0.4%', 'No'],
#  ['DENND4A', '4', '3', '499', '0.6%', 'No'],
#  ['DENND4C', '1', '1', '499', '0.2%', 'No'],
#  ['FAM199X', '1', '1', '499', '0.2%', 'No'],
#  ['IGF2R', '3', '3', '499', '0.6%', 'No'],
#  ['FGF16', '2', '2', '499', '0.4%', 'No'],
#  ['SDK1', '7', '6', '499', '1.2%', 'No'],
#  ['IFT27', '1', '1', '499', '0.2%', 'No'],
#  ['FGF11', '1', '1', '499', '0.2%', 'No'],
#  ['SDK2', '5', '3', '499', '0.6%', 'No'],
#  ['FGF10', '2', '2', '499', '0.4%', 'Yes'],
#  ['ZMYND15', '3', '3', '499', '0.6%', 'No'],
#  ['ZMYND19', '1', '1', '499', '0.2%', 'No'],
#  ['MYSM1', '1', '1', '499', '0.2%', 'No'],
#  ['GRM1', '11', '11', '499', '2.2%', 'No'],
#  ['PITPNC1', '2', '2', '499', '0.4%', 'No'],
#  ['GRM3', '4', '4', '499', '0.8%', 'Yes'],
#  ['GRM2', '3', '2', '499', '0.4%', 'No'],
#  ['CA1', '1', '1', '499', '0.2%', 'No'],
#  ['GRM5', '4', '3', '499', '0.6%', 'No'],
#  ['LASP1', '2', '2', '499', '0.4%', 'Yes'],
#  ['CYP26B1', '1', '1', '499', '0.2%', 'No'],
#  ['GRM4', '2', '2', '499', '0.4%', 'No'],
#  ['EEF2K', '5', '5', '499', '1.0%', 'No'],
#  ['CA3', '1', '1', '499', '0.2%', 'No'],
#  ['GRM7', '3', '3', '499', '0.6%', 'No'],
#  ['ZIC2', '2', '2', '499', '0.4%', 'No'],
#  ['CA2', '3', '3', '499', '0.6%', 'No'],
#  ['GRM6', '3', '2', '499', '0.4%', 'No'],
#  ['ZIC3', '2', '2', '499', '0.4%', 'No'],
#  ['CA4', '2', '2', '499', '0.4%', 'No'],
#  ['GRM8', '2', '2', '499', '0.4%', 'No'],
#  ['ZIC1', '3', '3', '499', '0.6%', 'No'],
#  ['CA6', '1', '1', '499', '0.2%', 'No'],
#  ['CA9', '2', '2', '499', '0.4%', 'No'],
#  ['MYBL2', '3', '2', '499', '0.4%', 'No'],
#  ['CA8', '4', '4', '499', '0.8%', 'No'],
#  ['MYBL1', '2', '2', '499', '0.4%', 'Yes'],
#  ['IFT56', '2', '2', '499', '0.4%', 'No'],
#  ['SUN2', '3', '3', '499', '0.6%', 'No'],
#  ['CAD', '9', '4', '499', '0.8%', 'Yes'],
#  ['ATP6AP2', '1', '1', '499', '0.2%', 'No'],
#  ['HUNK', '1', '1', '499', '0.2%', 'No'],
#  ['EEF1G', '1', '1', '499', '0.2%', 'No'],
#  ['ELF1', '1', '1', '499', '0.2%', 'No'],
#  ['CFAP100', '1', '1', '499', '0.2%', 'No'],
#  ['ELF2', '1', '1', '499', '0.2%', 'No'],
#  ['IFT43', '1', '1', '499', '0.2%', 'No'],
#  ['GFOD1', '1', '1', '499', '0.2%', 'No'],
#  ['EEF1D', '1', '1', '499', '0.2%', 'No'],
#  ['ELF4', '1', '1', '499', '0.2%', 'Yes'],
#  ['CAT', '2', '2', '499', '0.4%', 'No'],
#  ['GFOD2', '1', '1', '499', '0.2%', 'No'],
#  ['SPATA31D1', '4', '4', '499', '0.8%', 'No'],
#  ['ZMYND11', '1', '1', '499', '0.2%', 'No'],
#  ['IFT46', '1', '1', '499', '0.2%', 'No'],
#  ['ZMYND12', '4', '4', '499', '0.8%', 'No'],
#  ['SHANK3', '2', '2', '499', '0.4%', 'No'],
#  ['SHANK2', '8', '5', '499', '1.0%', 'No'],
#  ['PLEC', '9', '6', '499', '1.2%', 'No'],
#  ['SHANK1', '3', '3', '499', '0.6%', 'No'],
#  ['PSMB11', '2', '2', '499', '0.4%', 'No'],
#  ['GALT', '1', '1', '499', '0.2%', 'No'],
#  ['TAFAZZIN', '1', '1', '499', '0.2%', 'No'],
#  ['CBL', '1', '1', '499', '0.2%', 'Yes'],
#  ['IL1RL1', '1', '1', '499', '0.2%', 'No'],
#  ['IFT74', '1', '1', '499', '0.2%', 'No'],
#  ['IL1RL2', '2', '2', '499', '0.4%', 'No'],
#  ['NWD1', '6', '6', '499', '1.2%', 'No'],
#  ['MTA1', '2', '2', '499', '0.4%', 'No'],
#  ['SV2B', '2', '2', '499', '0.4%', 'No'],
#  ['CBS', '1', '1', '499', '0.2%', 'No'],
#  ['OXCT1', '5', '2', '499', '0.4%', 'No'],
#  ['SV2A', '3', '3', '499', '0.6%', 'No'],
#  ['TDG', '1', '1', '499', '0.2%', 'No'],
#  ['TBX20', '3', '3', '499', '0.6%', 'No'],
#  ['MVB12B', '1', '1', '499', '0.2%', 'No'],
#  ['SLIT1', '2', '2', '499', '0.4%', 'No'],
#  ['CLVS2', '1', '1', '499', '0.2%', 'No'],
#  ['DROSHA', '3', '3', '499', '0.6%', 'Yes'],
#  ['SLIT3', '4', '4', '499', '0.8%', 'Yes'],
#  ['RALY', '1', '1', '499', '0.2%', 'No'],
#  ['SLIT2', '3', '2', '499', '0.4%', 'Yes'],
#  ['MTA2', '1', '1', '499', '0.2%', 'No'],
#  ['SPATA31E1', '2', '2', '499', '0.4%', 'No'],
#  ['CLVS1', '2', '2', '499', '0.4%', 'No'],
#  ['OR1D5', '1', '1', '499', '0.2%', 'No'],
#  ['OR1D2', '1', '1', '499', '0.2%', 'No'],
#  ['RRM2', '1', '1', '499', '0.2%', 'No'],
#  ['HSD3B2', '2', '2', '499', '0.4%', 'No'],
#  ['HSD3B1', '2', '2', '499', '0.4%', 'Yes'],
#  ['ZIC4', '3', '3', '499', '0.6%', 'No'],
#  ['HS3ST6', '1', '1', '499', '0.2%', 'No'],
#  ['ZIC5', '3', '3', '499', '0.6%', 'No'],
#  ['SUOX', '1', '1', '499', '0.2%', 'No'],
#  ['TBX19', '2', '2', '499', '0.4%', 'No'],
#  ['WARS1', '1', '1', '499', '0.2%', 'No'],
#  ['TBX18', '4', '4', '499', '0.8%', 'No'],
#  ['WARS2', '2', '2', '499', '0.4%', 'No'],
#  ['CD2', '1', '1', '499', '0.2%', 'No'],
#  ['GALC', '1', '1', '499', '0.2%', 'No'],
#  ['TBX15', '2', '2', '499', '0.4%', 'No'],
#  ['CD4', '1', '1', '499', '0.2%', 'No'],
#  ['GALE', '1', '1', '499', '0.2%', 'No'],
#  ['TEC', '1', '1', '499', '0.2%', 'Yes'],
#  ['CD6', '1', '1', '499', '0.2%', 'No'],
#  ['TNIP1', '3', '3', '499', '0.6%', 'No'],
#  ['TNIP2', '1', '1', '499', '0.2%', 'No'],
#  ['TNIP3', '1', '1', '499', '0.2%', 'No'],
#  ['TBX10', '1', '1', '499', '0.2%', 'No'],
#  ['CD9', '1', '1', '499', '0.2%', 'No'],
#  ['TEK', '2', '2', '499', '0.4%', 'Yes'],
#  ['IPO13', '1', '1', '499', '0.2%', 'No'],
#  ['VPS29', '1', '1', '499', '0.2%', 'No'],
#  ['IPO11', '1', '1', '499', '0.2%', 'No'],
#  ['FRMPD3', '2', '1', '499', '0.2%', 'No'],
#  ['FRMPD4', '1', '1', '499', '0.2%', 'No'],
#  ['FRMPD1', '5', '4', '499', '0.8%', 'No'],
#  ['RRP1', '1', '1', '499', '0.2%', 'No'],
#  ['FRMPD2', '2', '2', '499', '0.4%', 'No'],
#  ['CWH43', '2', '2', '499', '0.4%', 'No'],
#  ['MSANTD4', '2', '2', '499', '0.4%', 'No'],
#  ['SLCO6A1', '3', '3', '499', '0.6%', 'No'],
#  ['GRPR', '1', '1', '499', '0.2%', 'No'],
#  ['CAPN15', '3', '3', '499', '0.6%', 'No'],
#  ['RRP9', '1', '1', '499', '0.2%', 'No'],
#  ['MTBP', '3', '2', '499', '0.4%', 'No'],
#  ['ALCAM', '2', '2', '499', '0.4%', 'No'],
#  ['TFG', '1', '1', '499', '0.2%', 'Yes'],
#  ['ZSCAN31', '1', '1', '499', '0.2%', 'No'],
#  ['SCN11A', '8', '8', '499', '1.6%', 'No'],
#  ['IGKV1-17', '1', '1', '499', '0.2%', 'No'],
#  ['ZSCAN30', '2', '2', '499', '0.4%', 'No'],
#  ['VPS35', '2', '2', '499', '0.4%', 'No'],
#  ['VPS39', '1', '1', '499', '0.2%', 'No'],
#  ['PRKCG', '1', '1', '499', '0.2%', 'No'],
#  ['VPS18', '1', '1', '499', '0.2%', 'No'],
#  ['PRKCI', '1', '1', '499', '0.2%', 'Yes'],
#  ['PRKCH', '1', '1', '499', '0.2%', 'No'],
#  ['TAAR8', '3', '3', '499', '0.6%', 'No'],
#  ['PRKCB', '2', '2', '499', '0.4%', 'No'],
#  ['TAAR9', '1', '1', '499', '0.2%', 'No'],
#  ['PRKCE', '2', '1', '499', '0.2%', 'No'],
#  ['DNAAF1', '5', '2', '499', '0.4%', 'No'],
#  ['TAAR6', '3', '3', '499', '0.6%', 'No'],
#  ['HUS1', '1', '1', '499', '0.2%', 'No'],
#  ['TAAR5', '1', '1', '499', '0.2%', 'No'],
#  ['AFAP1', '5', '4', '499', '0.8%', 'No'],
#  ['PRKCA', '2', '2', '499', '0.4%', 'No'],
#  ['TAAR2', '1', '1', '499', '0.2%', 'No'],
#  ['DNAAF5', '2', '2', '499', '0.4%', 'No'],
#  ['DNAAF4', '1', '1', '499', '0.2%', 'No'],
#  ['GANC', '3', '2', '499', '0.4%', 'No'],
#  ['DNAAF9', '4', '4', '499', '0.8%', 'No'],
#  ['DNAAF8', '1', '1', '499', '0.2%', 'No'],
#  ['BCAN', '5', '3', '499', '0.6%', 'No'],
#  ['BCAM', '3', '3', '499', '0.6%', 'No'],
#  ['MTAP', '1', '1', '499', '0.2%', 'Yes'],
#  ['SCN10A', '8', '8', '499', '1.6%', 'No'],
#  ['DAAM1', '4', '3', '499', '0.6%', 'No'],
#  ['IGKV1-27', '1', '1', '499', '0.2%', 'No'],
#  ['DAAM2', '4', '4', '499', '0.8%', 'No'],
#  ['PRKD3', '1', '1', '499', '0.2%', 'No'],
#  ['HECW2', '1', '1', '499', '0.2%', 'No'],
#  ['ZSCAN22', '1', '1', '499', '0.2%', 'No'],
#  ['KRTAP4-11', '25', '24', '499', '4.8%', 'No'],
#  ['ZSCAN21', '2', '2', '499', '0.4%', 'No'],
#  ['HECW1', '2', '2', '499', '0.4%', 'No'],
#  ['ZSCAN23', '1', '1', '499', '0.2%', 'No'],
#  ['PRKCQ', '3', '2', '499', '0.4%', 'No'],
#  ['PRKD2', '1', '1', '499', '0.2%', 'No'],
#  ['TARS2', '3', '3', '499', '0.6%', 'No'],
#  ['SRFBP1', '3', '3', '499', '0.6%', 'No'],
#  ['NUP98', '4', '4', '499', '0.8%', 'Yes'],
#  ['PRKD1', '2', '2', '499', '0.4%', 'Yes'],
#  ['TARS3', '1', '1', '499', '0.2%', 'No'],
#  ['ZSCAN25', '2', '2', '499', '0.4%', 'No'],
#  ['TARS1', '4', '4', '499', '0.8%', 'No'],
#  ['FREM1', '4', '4', '499', '0.8%', 'No'],
#  ['CFB', '3', '2', '499', '0.4%', 'No'],
#  ['VPS28', '1', '1', '499', '0.2%', 'No'],
#  ['FREM2', '13', '9', '499', '1.8%', 'No'],
#  ['ZSCAN29', '1', '1', '499', '0.2%', 'No'],
#  ['CFD', '1', '1', '499', '0.2%', 'No'],
#  ['CFH', '9', '8', '499', '1.6%', 'No'],
#  ['PRKDC', '11', '10', '499', '2.0%', 'Yes'],
#  ['CFI', '1', '1', '499', '0.2%', 'No'],
#  ['PRDM15', '1', '1', '499', '0.2%', 'No'],
#  ['METTL25B', '1', '1', '499', '0.2%', 'No'],
#  ['PRDM14', '2', '2', '499', '0.4%', 'Yes'],
#  ['PRDM12', '2', '2', '499', '0.4%', 'No'],
#  ['SDSL', '1', '1', '499', '0.2%', 'No'],
#  ['PRKCZ', '3', '3', '499', '0.6%', 'No'],
#  ['PRDM10', '1', '1', '499', '0.2%', 'No'],
#  ['MTDH', '2', '2', '499', '0.4%', 'No'],
#  ['RRP7A', '1', '1', '499', '0.2%', 'No'],
#  ['NUP85', '3', '3', '499', '0.6%', 'No'],
#  ['PRDM16', '3', '3', '499', '0.6%', 'Yes'],
#  ['ZSCAN10', '5', '5', '499', '1.0%', 'No'],
#  ['GAR1', '1', '1', '499', '0.2%', 'No'],
#  ['VPS11', '2', '2', '499', '0.4%', 'No'],
#  ['NUP88', '1', '1', '499', '0.2%', 'No'],
#  ['ST3GAL6', '1', '1', '499', '0.2%', 'No'],
#  ['CGA', '1', '1', '499', '0.2%', 'No'],
#  ['ST3GAL1', '2', '2', '499', '0.4%', 'No'],
#  ['ZSCAN16', '1', '1', '499', '0.2%', 'No'],
#  ['ST3GAL3', '1', '1', '499', '0.2%', 'No'],
#  ['VPS16', '2', '2', '499', '0.4%', 'No'],
#  ['FAM120AOS', '1', '1', '499', '0.2%', 'No'],
#  ['PLK4', '3', '2', '499', '0.4%', 'No'],
#  ['LRRC37A3', '1', '1', '499', '0.2%', 'No'],
#  ['PLK3', '3', '3', '499', '0.6%', 'No'],
#  ['LRRC37A2', '1', '1', '499', '0.2%', 'No'],
#  ['HOMER1', '1', '1', '499', '0.2%', 'No'],
#  ['MCAM', '1', '1', '499', '0.2%', 'No'],
#  ['PLK1', '1', '1', '499', '0.2%', 'No'],
#  ['CGN', '4', '3', '499', '0.6%', 'No'],
#  ['PEDS1-UBE2V1', '1', '1', '499', '0.2%', 'No'],
#  ['MEX3B', '1', '1', '499', '0.2%', 'No'],
#  ['MEX3A', '1', '1', '499', '0.2%', 'No'],
#  ['SETD4', '1', '1', '499', '0.2%', 'Yes'],
#  ['BTG4', '1', '1', '499', '0.2%', 'No'],
#  ['DENND1C', '1', '1', '499', '0.2%', 'No'],
#  ['BTG3', '2', '2', '499', '0.4%', 'No'],
#  ['SETD5', '7', '3', '499', '0.6%', 'Yes'],
#  ['DENND1B', '1', '1', '499', '0.2%', 'No'],
#  ['CDKN1A', '2', '2', '499', '0.4%', 'Yes'],
#  ['RARG', '1', '1', '499', '0.2%', 'No'],
#  ['SETD2', '10', '10', '499', '2.0%', 'Yes'],
#  ['BTG1', '1', '1', '499', '0.2%', 'Yes'],
#  ['CDKN1B', '1.990e-2', '6', '6', '499', '1.2%', 'Yes'],
#  ['SETD3', '1', '1', '499', '0.2%', 'Yes'],
#  ['DENND1A', '3', '2', '499', '0.4%', 'No'],
#  ['SETD6', '1', '1', '499', '0.2%', 'Yes'],
#  ['SETD7', '1', '1', '499', '0.2%', 'Yes'],
#  ['STON1', '1', '1', '499', '0.2%', 'No'],
#  ['CHM', '3', '3', '499', '0.6%', 'No'],
#  ['ASH2L', '1', '1', '499', '0.2%', 'No'],
#  ['STON2', '2', '1', '499', '0.2%', 'No'],
#  ['ASGR1', '1', '1', '499', '0.2%', 'No'],
#  ['ASGR2', '1', '1', '499', '0.2%', 'No'],
#  ['ADAMTSL1', '5', '5', '499', '1.0%', 'No'],
#  ['ADAMTSL5', '1', '1', '499', '0.2%', 'No'],
#  ['ADAMTSL4', '1', '1', '499', '0.2%', 'No'],
#  ['MTG1', '1', '1', '499', '0.2%', 'No'],
#  ['MTG2', '2', '2', '499', '0.4%', 'No'],
#  ['ADAMTSL3', '2', '2', '499', '0.4%', 'No'],
#  ['DENND11', '1', '1', '499', '0.2%', 'No'],
#  ['ADAMTSL2', '1', '1', '499', '0.2%', 'No'],
#  ['DENND10', '1', '1', '499', '0.2%', 'No'],
#  ['ELOA', '5', '5', '499', '1.0%', 'No'],
#  ['GAST', '1', '1', '499', '0.2%', 'No'],
#  ['ELOB', '1', '1', '499', '0.2%', 'No'],
#  ['RRP12', '4', '4', '499', '0.8%', 'No'],
#  ['CIC', '1', '1', '499', '0.2%', 'Yes'],
#  ['DENND2C', '1', '1', '499', '0.2%', 'No'],
#  ['EXOC7', '1', '1', '499', '0.2%', 'No'],
#  ['PLLP', '1', '1', '499', '0.2%', 'No'],
#  ['ZSCAN5B', '1', '1', '499', '0.2%', 'No'],
#  ['DENND2B', '3', '3', '499', '0.6%', 'No'],
#  ['DENND2A', '2', '2', '499', '0.4%', 'No'],
#  ['COPZ2', '1', '1', '499', '0.2%', 'No'],
#  ['ASH1L', '8', '8', '499', '1.6%', 'No'],
#  ['CIT', '3', '3', '499', '0.6%', 'No'],
#  ['ANGPTL7', '1', '1', '499', '0.2%', 'No'],
#  ['ANGPTL6', '2', '2', '499', '0.4%', 'No'],
#  ['MTF1', '5', '4', '499', '0.8%', 'No'],
#  ['RARA', '1', '1', '499', '0.2%', 'Yes'],
#  ['EXOC4', '2', '2', '499', '0.4%', 'No'],
#  ['PLIN4', '2', '2', '499', '0.4%', 'No'],
#  ['RARB', '3', '3', '499', '0.6%', 'No'],
#  ['PLIN3', '3', '3', '499', '0.6%', 'No'],
#  ['EXOC3', '4', '1', '499', '0.2%', 'No'],
#  ['ANGPTL2', '1', '1', '499', '0.2%', 'No'],
#  ['PLIN2', '1', '1', '499', '0.2%', 'No'],
#  ['EXOC6', '1', '1', '499', '0.2%', 'No'],
#  ['ANGPTL5', '1', '1', '499', '0.2%', 'No'],
#  ['PLIN1', '1', '1', '499', '0.2%', 'No'],
#  ['SINHCAF', '1', '1', '499', '0.2%', 'No'],
#  ['TKT', '2', '2', '499', '0.4%', 'No'],
#  ['RCCD1', '1', '1', '499', '0.2%', 'No'],
#  ['GART', '1', '1', '499', '0.2%', 'No'],
#  ['MOCS1', '2', '2', '499', '0.4%', 'No'],
#  ['GAS8', '2', '2', '499', '0.4%', 'No'],
#  ['EXOC2', '4', '4', '499', '0.8%', 'No'],
#  ['GAS7', '2', '2', '499', '0.4%', 'Yes'],
#  ['EXOC1', '4', '4', '499', '0.8%', 'No'],
#  ['PLIN5', '1', '1', '499', '0.2%', 'No'],
#  ['NFIX', '1', '1', '499', '0.2%', 'No'],
#  ['DCAF12L2', '2', '2', '499', '0.4%', 'No'],
#  ['DCAF12L1', '3', '3', '499', '0.6%', 'No'],
#  ['PRUNE2', '3', '1', '499', '0.2%', 'No'],
#  ['PAPSS2', '1', '1', '499', '0.2%', 'No'],
#  ['APOL4', '1', '1', '499', '0.2%', 'No'],
#  ['METTL21C', '1', '1', '499', '0.2%', 'No'],
#  ['ERMP1', '1', '1', '499', '0.2%', 'No'],
#  ['APOL6', '1', '1', '499', '0.2%', 'No'],
#  ['OLFML3', '1', '1', '499', '0.2%', 'No'],
#  ['ARRDC1-AS1', '1', '1', '499', '0.2%', 'No'],
#  ['RRP36', '5', '5', '499', '1.0%', 'No'],
#  ['CKB', '1', '1', '499', '0.2%', 'No'],
#  ['APOL1', '1', '1', '499', '0.2%', 'No'],
#  ['PAIP2', '1', '1', '499', '0.2%', 'No'],
#  ['MBNL3', '1', '1', '499', '0.2%', 'No'],
#  ['ZIM2', '2', '2', '499', '0.4%', 'No'],
#  ['APOL2', '1', '1', '499', '0.2%', 'No'],
#  ['ZIM3', '1', '1', '499', '0.2%', 'No'],
#  ['BCHE', '3', '3', '499', '0.6%', 'No'],
#  ['HIPK4', '1', '1', '499', '0.2%', 'No'],
#  ['CDKN2A', '1', '1', '499', '0.2%', 'Yes'],
#  ['IL10RA', '2', '2', '499', '0.4%', 'No'],
#  ['MOCOS', '2', '2', '499', '0.4%', 'No'],
#  ['ELP1', '2', '2', '499', '0.4%', 'No'],
#  ['GATC', '1', '1', '499', '0.2%', 'No'],
#  ['GATB', '1', '1', '499', '0.2%', 'No'],
#  ['ELP2', '2', '2', '499', '0.4%', 'Yes'],
#  ['ELP3', '1', '1', '499', '0.2%', 'No'],
#  ['SNCAIP', '4', '4', '499', '0.8%', 'Yes'],
#  ['ELP5', '1', '1', '499', '0.2%', 'No'],
#  ['HIPK1', '4', '3', '499', '0.6%', 'No'],
#  ['HIPK3', '1', '1', '499', '0.2%', 'No'],
#  ...]

# %%
mutated_genes_df = pd.DataFrame(processed_lines[1: ], columns = processed_lines[0])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/PycharmProjects/MultiOmicsFYP/.venv/lib/python3.10/site-packages/pandas/core/internals/construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File ~/PycharmProjects/MultiOmicsFYP/.venv/lib/python3.10/site-packages/pandas/core/internals/construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
#     988         f"{len(content)} columns"
#     989     )
#     990 if is_mi_list:
#     991     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 6 columns passed, passed data had 7 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 mutated_genes_df = pd.DataFrame(processed_lines[1: ], columns = processed_lines[0])
#
# File ~/PycharmProjects/MultiOmicsFYP/.venv/lib/python3.10/site-packages/pandas/core/frame.py:851, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     849     if columns is not None:
#     850         columns = ensure_index(columns)
# --> 851     arrays, columns, index = nested_data_to_arrays(
#     852         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     853         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     854         data,
#     855         columns,
#     856         index,  # type: ignore[arg-type]
#     857         dtype,
#     858     )
#     859     mgr = arrays_to_mgr(
#     860         arrays,
#     861         columns,
#    (...)
#     864         typ=manager,
#     865     )
#     866 else:
#
# File ~/PycharmProjects/MultiOmicsFYP/.venv/lib/python3.10/site-packages/pandas/core/internals/construction.py:520, in nested_data_to_arrays(data, columns, index, dtype)
#     517 if is_named_tuple(data[0]) and columns is None:
#     518     columns = ensure_index(data[0]._fields)
# --> 520 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     521 columns = ensure_index(columns)
#     523 if index is None:
#
# File ~/PycharmProjects/MultiOmicsFYP/.venv/lib/python3.10/site-packages/pandas/core/internals/construction.py:845, in to_arrays(data, columns, dtype)
#     842     data = [tuple(x) for x in data]
#     843     arr = _list_to_arrays(data)
# --> 845 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     846 return content, columns
#
# File ~/PycharmProjects/MultiOmicsFYP/.venv/lib/python3.10/site-packages/pandas/core/internals/construction.py:942, in _finalize_columns_and_data(content, columns, dtype)
#     939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
# --> 942     raise ValueError(err) from err
#     944 if len(contents) and contents[0].dtype == np.object_:
#     945     contents = convert_object_array(contents, dtype=dtype)
#
# ValueError: 6 columns passed, passed data had 7 columns

# %%
len(processed_lines[1])
# Out:
# 6

# %%
#Some of the lines Have more than 6 elements
for a, b in enumerate(processed_lines):
    if len(b) > 6:
        print(f'Line No: {a + 1} | Line: {b}')
# Out:
# Line No: 546 | Line: ['PITPNM2', '1.640e-12', '2', '1', '499', '0.2%', 'No']
# Line No: 623 | Line: ['RAG1', '3.530e-2', '11', '10', '499', '2.0%', 'No']
# Line No: 910 | Line: ['CDKN1B', '1.990e-2', '6', '6', '499', '1.2%', 'Yes']
# Line No: 1343 | Line: ['EMG1', '1.950e-3', '4', '4', '499', '0.8%', 'No']
# Line No: 1694 | Line: ['SBNO1', '5.030e-2', '6', '5', '499', '1.0%', 'No']
# Line No: 1764 | Line: ['PIK3CA', '1.840e-2', '16', '14', '499', '2.8%', 'Yes']
# Line No: 1812 | Line: ['VPS35L', '1.640e-12', '2', '2', '499', '0.4%', 'No']
# Line No: 2123 | Line: ['TAF1L', '4.590e-2', '10', '10', '499', '2.0%', 'No']
# Line No: 2771 | Line: ['HSPA8', '8.850e-2', '7', '7', '499', '1.4%', 'No']
# Line No: 2927 | Line: ['OR4P4', '4.700e-3', '5', '5', '499', '1.0%', 'No']
# Line No: 2955 | Line: ['EPB41L3', '2.760e-2', '15', '12', '499', '2.4%', 'No']
# Line No: 3077 | Line: ['SLC27A4', '1.640e-12', '2', '2', '499', '0.4%', 'No']
# Line No: 3401 | Line: ['BHLHE22', '2.680e-2', '3', '3', '499', '0.6%', 'No']
# Line No: 3508 | Line: ['OR5L2', '2.440e-2', '6', '6', '499', '1.2%', 'No']
# Line No: 3658 | Line: ['SALL1', '4.840e-3', '13', '12', '499', '2.4%', 'No']
# Line No: 3933 | Line: ['OR4D5', '1.070e-2', '6', '6', '499', '1.2%', 'No']
# Line No: 3958 | Line: ['OR4C6', '3.530e-2', '6', '6', '499', '1.2%', 'No']
# Line No: 4603 | Line: ['PRG4', '9.870e-2', '11', '10', '499', '2.0%', 'No']
# Line No: 4666 | Line: ['SORCS1', '7.520e-2', '10', '10', '499', '2.0%', 'No']
# Line No: 4672 | Line: ['NBPF1', '2.410e-2', '32', '27', '499', '5.4%', 'No']
# Line No: 5379 | Line: ['ZMYM3', '4.700e-3', '13', '12', '499', '2.4%', 'Yes']
# Line No: 5629 | Line: ['DPYSL2', '1.640e-12', '2', '2', '499', '0.4%', 'No']
# Line No: 5849 | Line: ['CLPTM1L', '1.640e-12', '3', '2', '499', '0.4%', 'No']
# Line No: 5855 | Line: ['PTEN', '6.560e-11', '17', '17', '499', '3.4%', 'Yes']
# Line No: 5865 | Line: ['NKX3-1', '4.500e-3', '5', '5', '499', '1.0%', 'Yes']
# Line No: 5885 | Line: ['CANT1', '2.410e-2', '3', '3', '499', '0.6%', 'Yes']
# Line No: 5966 | Line: ['TP53', '1.640e-12', '64', '61', '499', '12.2%', 'Yes']
# Line No: 6181 | Line: ['ETV3', '1.950e-3', '5', '5', '499', '1.0%', 'No']
# Line No: 6677 | Line: ['NEIL1', '1.640e-12', '2', '2', '499', '0.4%', 'No']
# Line No: 6757 | Line: ['ACTRT1', '3.530e-2', '5', '4', '499', '0.8%', 'No']
# Line No: 7104 | Line: ['OR10G8', '7.450e-2', '7', '6', '499', '1.2%', 'No']
# Line No: 7467 | Line: ['FOXA1', '1.640e-12', '29', '28', '499', '5.6%', 'Yes']
# Line No: 8176 | Line: ['NTM', '9.650e-3', '7', '7', '499', '1.4%', 'No']
# Line No: 8224 | Line: ['LMOD2', '6.960e-3', '6', '6', '499', '1.2%', 'No']
# Line No: 8353 | Line: ['MED12', '1.640e-12', '8', '8', '499', '1.6%', 'Yes']
# Line No: 8412 | Line: ['SPOP', '1.640e-12', '58', '57', '499', '11.4%', 'Yes']
# Line No: 8901 | Line: ['MUC17', '8.750e-3', '36', '33', '499', '6.6%', 'No']
# Line No: 9633 | Line: ['IDH1', '5.630e-3', '6', '6', '499', '1.2%', 'Yes']
# Line No: 9682 | Line: ['KDM6A', '6.740e-3', '14', '14', '499', '2.8%', 'Yes']
# Line No: 9943 | Line: ['COL11A1', '1.530e-2', '16', '14', '499', '2.8%', 'No']
# Line No: 10294 | Line: ['ANO4', '7.060e-2', '9', '9', '499', '1.8%', 'No']
# Line No: 10604 | Line: ['BRAF', '2.350e-3', '8', '8', '499', '1.6%', 'Yes']
# Line No: 10684 | Line: ['LCE2D', '3.070e-2', '4', '4', '499', '0.8%', 'No']
# Line No: 11011 | Line: ['ATM', '1.360e-4', '22', '22', '499', '4.4%', 'Yes']
# Line No: 11076 | Line: ['CTNNB1', '1.640e-12', '13', '13', '499', '2.6%', 'Yes']

# %%
#The exponential values have to be removed from the lists
processed_lines = [i[:1] + i[2: ] if len(i) > 6 else i for i in processed_lines]

# %%
processed_lines
# Out:
# [['Gene',
#   'MutSig(Q-value)',
#   '# Mut',
#   '#Profiled Samples',
#   'Freq',
#   'Is Cancer Gene (source: OncoKB)'],
#  ['PGLYRP3', '1', '1', '499', '0.2%', 'No'],
#  ['PGLYRP2', '3', '3', '499', '0.6%', 'No'],
#  ['TFRC', '1', '1', '499', '0.2%', 'Yes'],
#  ['HTR4', '1', '1', '499', '0.2%', 'No'],
#  ['PTPDC1', '1', '1', '499', '0.2%', 'No'],
#  ['CRHBP', '2', '2', '499', '0.4%', 'No'],
#  ['HTR6', '2', '2', '499', '0.4%', 'No'],
#  ['CAPNS1', '2', '2', '499', '0.4%', 'No'],
#  ['SCP2', '3', '2', '499', '0.4%', 'No'],
#  ['LURAP1L', '3', '3', '499', '0.6%', 'No'],
#  ['BBX', '2', '2', '499', '0.4%', 'No'],
#  ['PRKACA', '2', '2', '499', '0.4%', 'Yes'],
#  ['SPATA31G1', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF17', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF18', '3', '2', '499', '0.4%', 'No'],
#  ['ZNF19', '2', '2', '499', '0.4%', 'No'],
#  ['SDS', '1', '1', '499', '0.2%', 'No'],
#  ['UNC5A', '1', '1', '499', '0.2%', 'No'],
#  ['UNC5B', '5', '5', '499', '1.0%', 'No'],
#  ['SECISBP2', '1', '1', '499', '0.2%', 'No'],
#  ['RC3H1', '2', '2', '499', '0.4%', 'No'],
#  ['INSYN1', '1', '1', '499', '0.2%', 'No'],
#  ['UNC5D', '3', '3', '499', '0.6%', 'No'],
#  ['ZNF14', '1', '1', '499', '0.2%', 'No'],
#  ['RC3H2', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF16', '1', '1', '499', '0.2%', 'No'],
#  ['BCR', '2', '2', '499', '0.4%', 'Yes'],
#  ['LARS2', '2', '2', '499', '0.4%', 'No'],
#  ['SCO1', '1', '1', '499', '0.2%', 'No'],
#  ['TFR2', '1', '1', '499', '0.2%', 'No'],
#  ['LARS1', '3', '3', '499', '0.6%', 'No'],
#  ['DDIT4', '2', '2', '499', '0.4%', 'No'],
#  ['ORAI3', '1', '1', '499', '0.2%', 'No'],
#  ['AGTR1', '3', '3', '499', '0.6%', 'No'],
#  ['HOATZ', '1', '1', '499', '0.2%', 'No'],
#  ['SPATA31H1', '4', '4', '499', '0.8%', 'No'],
#  ['SF1', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF28', '3', '3', '499', '0.6%', 'No'],
#  ['UNC119B', '1', '1', '499', '0.2%', 'No'],
#  ['COL13A1', '1', '1', '499', '0.2%', 'No'],
#  ['SHMT2', '1', '1', '499', '0.2%', 'No'],
#  ['AASDH', '2', '2', '499', '0.4%', 'No'],
#  ['SHMT1', '1', '1', '499', '0.2%', 'No'],
#  ['NPRL3', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF20', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF23', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF24', '1', '1', '499', '0.2%', 'Yes'],
#  ['ADAMTS12', '3', '3', '499', '0.6%', 'No'],
#  ['ADAMTS10', '5', '3', '499', '0.6%', 'No'],
#  ['ADAMTS16', '6', '5', '499', '1.0%', 'No'],
#  ['ADAMTS15', '2', '2', '499', '0.4%', 'No'],
#  ['ADAMTS14', '3', '3', '499', '0.6%', 'No'],
#  ['ADAMTS13', '4', '4', '499', '0.8%', 'No'],
#  ['LARP1', '7', '6', '499', '1.2%', 'No'],
#  ['RDH12', '1', '1', '499', '0.2%', 'No'],
#  ['ADAMTS19', '5', '5', '499', '1.0%', 'No'],
#  ['RDH10', '1', '1', '499', '0.2%', 'No'],
#  ['ADAMTS18', '3', '3', '499', '0.6%', 'No'],
#  ['ADAMTS17', '3', '2', '499', '0.4%', 'No'],
#  ['RDH16', '1', '1', '499', '0.2%', 'No'],
#  ['GSTM3', '1', '1', '499', '0.2%', 'No'],
#  ['GSTM2', '2', '2', '499', '0.4%', 'No'],
#  ['PRPF38B', '2', '2', '499', '0.4%', 'No'],
#  ['NEBL', '4', '3', '499', '0.6%', 'No'],
#  ['ZNF34', '1', '1', '499', '0.2%', 'No'],
#  ['L1CAM', '7', '7', '499', '1.4%', 'No'],
#  ['ZNF35', '2', '2', '499', '0.4%', 'No'],
#  ['LARP4', '3', '3', '499', '0.6%', 'No'],
#  ['DHFR', '2', '2', '499', '0.4%', 'No'],
#  ['MOV10', '3', '3', '499', '0.6%', 'No'],
#  ['PPFIBP1', '5', '4', '499', '0.8%', 'Yes'],
#  ['PPFIBP2', '5', '3', '499', '0.6%', 'No'],
#  ['FXYD3', '1', '1', '499', '0.2%', 'No'],
#  ['STRC', '5', '5', '499', '1.0%', 'No'],
#  ['ZNF30', '3', '2', '499', '0.4%', 'No'],
#  ['STRN', '2', '1', '499', '0.2%', 'Yes'],
#  ['L1TD1', '1', '1', '499', '0.2%', 'No'],
#  ['DZIP3', '2', '2', '499', '0.4%', 'No'],
#  ['GSTM5', '1', '1', '499', '0.2%', 'No'],
#  ['KCNC1', '3', '3', '499', '0.6%', 'No'],
#  ['KCNC3', '1', '1', '499', '0.2%', 'No'],
#  ['KCNC4', '3', '3', '499', '0.6%', 'No'],
#  ['PRKAG1', '3', '3', '499', '0.6%', 'No'],
#  ['ZNF43', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF44', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF45', '1', '1', '499', '0.2%', 'No'],
#  ['FRG2B', '1', '1', '499', '0.2%', 'No'],
#  ['PRKAG3', '1', '1', '499', '0.2%', 'No'],
#  ['SHD', '1', '1', '499', '0.2%', 'No'],
#  ['MMP21', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF48', '3', '3', '499', '0.6%', 'No'],
#  ['MMP20', '1', '1', '499', '0.2%', 'No'],
#  ['NPAP1', '4', '4', '499', '0.8%', 'No'],
#  ['M1AP', '1', '1', '499', '0.2%', 'No'],
#  ['SHE', '2', '2', '499', '0.4%', 'No'],
#  ['SHH', '2', '2', '499', '0.4%', 'No'],
#  ['MMP25', '1', '1', '499', '0.2%', 'No'],
#  ['MMP24', '1', '1', '499', '0.2%', 'No'],
#  ['MMP26', '3', '3', '499', '0.6%', 'No'],
#  ['ZNF41', '1', '1', '499', '0.2%', 'No'],
#  ['NEFM', '2', '2', '499', '0.4%', 'No'],
#  ['STUM', '1', '1', '499', '0.2%', 'No'],
#  ['MYBPC3', '3', '3', '499', '0.6%', 'No'],
#  ['APC2', '3', '2', '499', '0.4%', 'No'],
#  ['MYBPC1', '2', '2', '499', '0.4%', 'No'],
#  ['MYBPC2', '5', '5', '499', '1.0%', 'No'],
#  ['KCND2', '2', '2', '499', '0.4%', 'No'],
#  ['GSTO2', '1', '1', '499', '0.2%', 'No'],
#  ['KCND3', '4', '4', '499', '0.8%', 'No'],
#  ['GSTO1', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF57', '2', '1', '499', '0.2%', 'No'],
#  ['MMP12', '1', '1', '499', '0.2%', 'No'],
#  ['MMP11', '2', '2', '499', '0.4%', 'No'],
#  ['MMP14', '1', '1', '499', '0.2%', 'No'],
#  ['MMP13', '1', '1', '499', '0.2%', 'No'],
#  ['MMP16', '2', '2', '499', '0.4%', 'No'],
#  ['PTRH2', '1', '1', '499', '0.2%', 'No'],
#  ['MMP17', '2', '2', '499', '0.4%', 'No'],
#  ['RAPGEF1', '4', '4', '499', '0.8%', 'No'],
#  ['MMP19', '2', '2', '499', '0.4%', 'No'],
#  ['RAPGEF2', '2', '2', '499', '0.4%', 'No'],
#  ['CRYAA', '1', '1', '499', '0.2%', 'No'],
#  ['RAPGEF6', '5', '5', '499', '1.0%', 'No'],
#  ['RAPGEF3', '1', '1', '499', '0.2%', 'No'],
#  ['RAPGEF4', '3', '3', '499', '0.6%', 'No'],
#  ['TRUB1', '2', '2', '499', '0.4%', 'No'],
#  ['TRUB2', '2', '2', '499', '0.4%', 'No'],
#  ['PKN3', '2', '1', '499', '0.2%', 'No'],
#  ['GSTP1', '1', '1', '499', '0.2%', 'No'],
#  ['KCNA1', '1', '1', '499', '0.2%', 'No'],
#  ['SYNPO2', '2', '2', '499', '0.4%', 'No'],
#  ['KCNA2', '1', '1', '499', '0.2%', 'No'],
#  ['KCNA3', '6', '5', '499', '1.0%', 'No'],
#  ['ADAM22', '1', '1', '499', '0.2%', 'No'],
#  ['KCNA4', '2', '2', '499', '0.4%', 'No'],
#  ['ADAM21', '1', '1', '499', '0.2%', 'No'],
#  ['KCNA5', '3', '3', '499', '0.6%', 'No'],
#  ['ADAM20', '4', '3', '499', '0.6%', 'No'],
#  ['KCNA6', '2', '2', '499', '0.4%', 'No'],
#  ['KCNA7', '2', '2', '499', '0.4%', 'No'],
#  ['SDAD1', '1', '1', '499', '0.2%', 'No'],
#  ['ADAM29', '8', '8', '499', '1.6%', 'No'],
#  ['ADAM28', '3', '3', '499', '0.6%', 'No'],
#  ['ADAM23', '5', '5', '499', '1.0%', 'No'],
#  ['PLAGL2', '1', '1', '499', '0.2%', 'No'],
#  ['RICTOR', '1', '1', '499', '0.2%', 'Yes'],
#  ['SPDEF', '1', '1', '499', '0.2%', 'No'],
#  ['MBD3', '2', '2', '499', '0.4%', 'No'],
#  ['MBD4', '2', '2', '499', '0.4%', 'Yes'],
#  ['MBD5', '1', '1', '499', '0.2%', 'No'],
#  ['MBD6', '2', '2', '499', '0.4%', 'Yes'],
#  ['PKLR', '1', '1', '499', '0.2%', 'No'],
#  ['BIK', '1', '1', '499', '0.2%', 'No'],
#  ['KCNB1', '5', '5', '499', '1.0%', 'No'],
#  ['MBD1', '3', '3', '499', '0.6%', 'No'],
#  ['KCNB2', '7', '7', '499', '1.4%', 'No'],
#  ['SCTR', '3', '3', '499', '0.6%', 'No'],
#  ['BMP8B', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF76', '1', '1', '499', '0.2%', 'No'],
#  ['BBOX1', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF77', '1', '1', '499', '0.2%', 'No'],
#  ['ADAM30', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF79', '1', '1', '499', '0.2%', 'No'],
#  ['TARBP2', '1', '1', '499', '0.2%', 'No'],
#  ['ARCN1', '1', '1', '499', '0.2%', 'No'],
#  ['TARBP1', '4', '3', '499', '0.6%', 'No'],
#  ['ZNF71', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF74', '2', '1', '499', '0.2%', 'No'],
#  ['PKN2', '4', '3', '499', '0.6%', 'No'],
#  ['PKN1', '3', '3', '499', '0.6%', 'No'],
#  ['KCNG1', '2', '2', '499', '0.4%', 'No'],
#  ['KCNG2', '3', '3', '499', '0.6%', 'No'],
#  ['MTCH2', '1', '1', '499', '0.2%', 'No'],
#  ['KCNG4', '3', '2', '499', '0.4%', 'No'],
#  ['RASL11B', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO27', '1', '1', '499', '0.2%', 'No'],
#  ['PDCD5', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO28', '1', '1', '499', '0.2%', 'No'],
#  ['GOLIM4', '3', '3', '499', '0.6%', 'No'],
#  ['IL1RAP', '2', '2', '499', '0.4%', 'No'],
#  ['MSI2', '1', '1', '499', '0.2%', 'Yes'],
#  ['APEH', '2', '2', '499', '0.4%', 'No'],
#  ['FBXO21', '2', '2', '499', '0.4%', 'No'],
#  ['FADS3', '2', '2', '499', '0.4%', 'No'],
#  ['POTEM', '7', '7', '499', '1.4%', 'No'],
#  ['SLK', '2', '2', '499', '0.4%', 'No'],
#  ['FNTA', '1', '1', '499', '0.2%', 'No'],
#  ['POTEH', '4', '3', '499', '0.6%', 'No'],
#  ['MYBPHL', '2', '2', '499', '0.4%', 'No'],
#  ['POFUT1', '1', '1', '499', '0.2%', 'No'],
#  ['FNTB', '1', '1', '499', '0.2%', 'No'],
#  ['NFATC2IP', '1', '1', '499', '0.2%', 'No'],
#  ['POTED', '1', '1', '499', '0.2%', 'No'],
#  ['TNFRSF8', '3', '3', '499', '0.6%', 'No'],
#  ['NEK1', '3', '3', '499', '0.6%', 'No'],
#  ['POTEE', '3', '3', '499', '0.6%', 'No'],
#  ['MAP3K8', '1', '1', '499', '0.2%', 'No'],
#  ['POTEF', '4', '4', '499', '0.8%', 'No'],
#  ['MAP3K9', '12', '11', '499', '2.2%', 'No'],
#  ['POTEG', '2', '2', '499', '0.4%', 'No'],
#  ['MAP3K7', '2', '2', '499', '0.4%', 'Yes'],
#  ['TNFRSF4', '2', '2', '499', '0.4%', 'No'],
#  ['MAP3K4', '3', '2', '499', '0.4%', 'No'],
#  ['KCNH1', '2', '2', '499', '0.4%', 'No'],
#  ['MAP3K5', '2', '2', '499', '0.4%', 'No'],
#  ['POTEC', '13', '13', '499', '2.6%', 'No'],
#  ['KCNH2', '2', '2', '499', '0.4%', 'No'],
#  ['PIAS4', '3', '2', '499', '0.4%', 'No'],
#  ['PIAS3', '2', '2', '499', '0.4%', 'No'],
#  ['KCNH3', '1', '1', '499', '0.2%', 'No'],
#  ['KCNH4', '3', '3', '499', '0.6%', 'No'],
#  ['KCNH5', '5', '5', '499', '1.0%', 'No'],
#  ['DGAT2', '1', '1', '499', '0.2%', 'No'],
#  ['DGAT1', '1', '1', '499', '0.2%', 'No'],
#  ['FBXW8', '1', '1', '499', '0.2%', 'No'],
#  ['KCNH6', '2', '2', '499', '0.4%', 'No'],
#  ['KCNH7', '6', '6', '499', '1.2%', 'No'],
#  ['STX8', '2', '1', '499', '0.2%', 'No'],
#  ['KCNH8', '3', '3', '499', '0.6%', 'No'],
#  ['FBXO16', '2', '2', '499', '0.4%', 'No'],
#  ['STX7', '1', '1', '499', '0.2%', 'No'],
#  ['FBXW9', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO10', '2', '2', '499', '0.4%', 'No'],
#  ['SRCIN1', '1', '1', '499', '0.2%', 'No'],
#  ['MSH6', '3', '3', '499', '0.6%', 'Yes'],
#  ['NPAS4', '2', '2', '499', '0.4%', 'No'],
#  ['MSH2', '2', '2', '499', '0.4%', 'Yes'],
#  ['DMTF1', '4', '4', '499', '0.8%', 'No'],
#  ['MSH3', '9', '8', '499', '1.6%', 'Yes'],
#  ['MSH4', '2', '2', '499', '0.4%', 'No'],
#  ['MSH5', '1', '1', '499', '0.2%', 'No'],
#  ['PKP2', '2', '2', '499', '0.4%', 'No'],
#  ['PKP1', '2', '1', '499', '0.2%', 'No'],
#  ['PKP4', '1', '1', '499', '0.2%', 'No'],
#  ['BLK', '1', '1', '499', '0.2%', 'No'],
#  ['KCNE2', '1', '1', '499', '0.2%', 'No'],
#  ['KCNE3', '2', '2', '499', '0.4%', 'No'],
#  ['IREB2', '4', '4', '499', '0.8%', 'No'],
#  ['FBXO45', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO46', '3', '3', '499', '0.6%', 'No'],
#  ['FBXO43', '2', '2', '499', '0.4%', 'No'],
#  ['CES5A', '1', '1', '499', '0.2%', 'No'],
#  ['NPAS2', '1', '1', '499', '0.2%', 'No'],
#  ['CCDC144A', '3', '3', '499', '0.6%', 'No'],
#  ['FBXO42', '5', '4', '499', '0.8%', 'No'],
#  ['FBXO40', '1', '1', '499', '0.2%', 'No'],
#  ['RAP1A', '1', '1', '499', '0.2%', 'No'],
#  ['NDOR1', '1', '1', '499', '0.2%', 'No'],
#  ['ZKSCAN7', '1', '1', '499', '0.2%', 'No'],
#  ['ZKSCAN8', '1', '1', '499', '0.2%', 'No'],
#  ['MBIP', '1', '1', '499', '0.2%', 'No'],
#  ['ZKSCAN2', '1', '1', '499', '0.2%', 'No'],
#  ['ZKSCAN5', '3', '3', '499', '0.6%', 'No'],
#  ['CERT1', '3', '3', '499', '0.6%', 'No'],
#  ['ZKSCAN1', '2', '2', '499', '0.4%', 'No'],
#  ['NEK8', '1', '1', '499', '0.2%', 'No'],
#  ['KCNF1', '1', '1', '499', '0.2%', 'No'],
#  ['NOP14', '1', '1', '499', '0.2%', 'No'],
#  ['SDF2L1', '2', '2', '499', '0.4%', 'No'],
#  ['HTR1E', '6', '6', '499', '1.2%', 'No'],
#  ['NEK4', '3', '2', '499', '0.4%', 'No'],
#  ['RASL10A', '1', '1', '499', '0.2%', 'No'],
#  ['NOP16', '1', '1', '499', '0.2%', 'No'],
#  ['API5', '1', '1', '499', '0.2%', 'No'],
#  ['NEK6', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO38', '4', '4', '499', '0.8%', 'No'],
#  ['HTR1D', '2', '2', '499', '0.4%', 'No'],
#  ['FBXO39', '2', '2', '499', '0.4%', 'No'],
#  ['HTR1A', '3', '3', '499', '0.6%', 'No'],
#  ['FBXO36', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO34', '3', '3', '499', '0.6%', 'No'],
#  ['BMX', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO32', '1', '1', '499', '0.2%', 'No'],
#  ['G6PC1', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO30', '1', '1', '499', '0.2%', 'No'],
#  ['FAM90A1', '2', '2', '499', '0.4%', 'No'],
#  ['G6PC2', '1', '1', '499', '0.2%', 'No'],
#  ['SON', '3', '3', '499', '0.6%', 'No'],
#  ['LRCH1', '4', '4', '499', '0.8%', 'No'],
#  ['G6PC3', '2', '2', '499', '0.4%', 'No'],
#  ['SP2', '1', '1', '499', '0.2%', 'No'],
#  ['SP1', '2', '2', '499', '0.4%', 'No'],
#  ['SP4', '6', '5', '499', '1.0%', 'No'],
#  ['SP3', '3', '3', '499', '0.6%', 'No'],
#  ['SP8', '5', '5', '499', '1.0%', 'No'],
#  ['LRCH4', '1', '1', '499', '0.2%', 'No'],
#  ['SLC49A4', '4', '3', '499', '0.6%', 'No'],
#  ['SLC49A3', '1', '1', '499', '0.2%', 'No'],
#  ['BCAR3', '3', '3', '499', '0.6%', 'No'],
#  ['KCNK5', '3', '3', '499', '0.6%', 'No'],
#  ['PIWIL2', '4', '3', '499', '0.6%', 'No'],
#  ['PIWIL1', '7', '6', '499', '1.2%', 'No'],
#  ['KCNK6', '1', '1', '499', '0.2%', 'No'],
#  ['ALAS2', '1', '1', '499', '0.2%', 'No'],
#  ['KCNK7', '1', '1', '499', '0.2%', 'No'],
#  ['BMP10', '1', '1', '499', '0.2%', 'No'],
#  ['ALAS1', '3', '2', '499', '0.4%', 'No'],
#  ['PIWIL3', '2', '2', '499', '0.4%', 'No'],
#  ['ONECUT2', '3', '3', '499', '0.6%', 'Yes'],
#  ['KCNK9', '2', '2', '499', '0.4%', 'No'],
#  ['MTCL1', '6', '6', '499', '1.2%', 'No'],
#  ['MTCL2', '3', '3', '499', '0.6%', 'No'],
#  ['ONECUT1', '2', '2', '499', '0.4%', 'No'],
#  ['MTCL3', '4', '2', '499', '0.4%', 'No'],
#  ['HTR2B', '2', '2', '499', '0.4%', 'No'],
#  ['DYSF', '4', '2', '499', '0.4%', 'No'],
#  ['HTR2C', '3', '3', '499', '0.6%', 'No'],
#  ['PPWD1', '1', '1', '499', '0.2%', 'No'],
#  ['HTR2A', '2', '2', '499', '0.4%', 'No'],
#  ['MSLN', '2', '2', '499', '0.4%', 'No'],
#  ['BICD1', '3', '3', '499', '0.6%', 'No'],
#  ['BICD2', '4', '3', '499', '0.6%', 'No'],
#  ['BMP15', '1', '1', '499', '0.2%', 'No'],
#  ['SPN', '1', '1', '499', '0.2%', 'No'],
#  ['UNC80', '3', '3', '499', '0.6%', 'No'],
#  ['SPR', '1', '1', '499', '0.2%', 'No'],
#  ['OR56B1', '1', '1', '499', '0.2%', 'No'],
#  ['SPDL1', '2', '2', '499', '0.4%', 'No'],
#  ['NEO1', '4', '3', '499', '0.6%', 'No'],
#  ['BCAS2', '1', '1', '499', '0.2%', 'No'],
#  ['BCAS1', '1', '1', '499', '0.2%', 'No'],
#  ['BCAS4', '1', '1', '499', '0.2%', 'No'],
#  ['UNC45A', '1', '1', '499', '0.2%', 'No'],
#  ['CERS3', '1', '1', '499', '0.2%', 'No'],
#  ['SLC36A1', '1', '1', '499', '0.2%', 'No'],
#  ['CERS4', '1', '1', '499', '0.2%', 'No'],
#  ['UNC45B', '2', '2', '499', '0.4%', 'No'],
#  ['CERS5', '1', '1', '499', '0.2%', 'No'],
#  ['SLC36A3', '1', '1', '499', '0.2%', 'No'],
#  ['SLC36A2', '3', '2', '499', '0.4%', 'No'],
#  ['CERS6', '1', '1', '499', '0.2%', 'No'],
#  ['RNASET2', '1', '1', '499', '0.2%', 'No'],
#  ['VPS13C', '7', '7', '499', '1.4%', 'No'],
#  ['DHPS', '1', '1', '499', '0.2%', 'No'],
#  ['VPS13D', '13', '8', '499', '1.6%', 'No'],
#  ['VPS13A', '4', '3', '499', '0.6%', 'No'],
#  ['MSL2', '1', '1', '499', '0.2%', 'No'],
#  ['HTR3C', '1', '1', '499', '0.2%', 'No'],
#  ['VPS13B', '11', '8', '499', '1.6%', 'No'],
#  ['HTR3B', '1', '1', '499', '0.2%', 'No'],
#  ['RABGGTA', '1', '1', '499', '0.2%', 'No'],
#  ['CES4A', '3', '3', '499', '0.6%', 'No'],
#  ['ADAMTS20', '8', '7', '499', '1.4%', 'No'],
#  ['MSL1', '1', '1', '499', '0.2%', 'No'],
#  ['NEMF', '2', '2', '499', '0.4%', 'No'],
#  ['BMP2K', '7', '7', '499', '1.4%', 'No'],
#  ['BPI', '2', '2', '499', '0.4%', 'No'],
#  ['BCAT1', '1', '1', '499', '0.2%', 'No'],
#  ['OR56A4', '1', '1', '499', '0.2%', 'No'],
#  ['GAPDH', '1', '1', '499', '0.2%', 'No'],
#  ['OR56A3', '3', '3', '499', '0.6%', 'No'],
#  ['BCAT2', '2', '1', '499', '0.2%', 'No'],
#  ['CERS2', '2', '2', '499', '0.4%', 'No'],
#  ['OR56A1', '2', '2', '499', '0.4%', 'No'],
#  ['BLTP3A', '5', '5', '499', '1.0%', 'No'],
#  ['PRKAA2', '5', '5', '499', '1.0%', 'No'],
#  ['BLTP3B', '3', '2', '499', '0.4%', 'No'],
#  ['C1S', '4', '4', '499', '0.8%', 'No'],
#  ['UHRF2', '1', '1', '499', '0.2%', 'No'],
#  ['LENG8', '5', '2', '499', '0.4%', 'No'],
#  ['MLLT1', '2', '2', '499', '0.4%', 'Yes'],
#  ['U2AF1', '1', '1', '499', '0.2%', 'Yes'],
#  ['SRI', '2', '2', '499', '0.4%', 'No'],
#  ['MLLT3', '2', '2', '499', '0.4%', 'Yes'],
#  ['MLLT6', '3', '2', '499', '0.4%', 'Yes'],
#  ['SRM', '1', '1', '499', '0.2%', 'No'],
#  ['AWAT1', '1', '1', '499', '0.2%', 'No'],
#  ['U2AF2', '1', '1', '499', '0.2%', 'Yes'],
#  ['AWAT2', '1', '1', '499', '0.2%', 'No'],
#  ['KRIT1', '3', '3', '499', '0.6%', 'No'],
#  ['TSPOAP1', '5', '3', '499', '0.6%', 'No'],
#  ['BBLN', '1', '1', '499', '0.2%', 'No'],
#  ['KCNJ2', '2', '2', '499', '0.4%', 'No'],
#  ['KCNJ4', '3', '3', '499', '0.6%', 'No'],
#  ['NOP56', '1', '1', '499', '0.2%', 'No'],
#  ['KCNJ5', '2', '2', '499', '0.4%', 'Yes'],
#  ['KCNJ6', '2', '2', '499', '0.4%', 'No'],
#  ['NOP58', '2', '2', '499', '0.4%', 'No'],
#  ['COL26A1', '3', '3', '499', '0.6%', 'No'],
#  ['SSB', '4', '4', '499', '0.8%', 'No'],
#  ['KCNJ8', '1', '1', '499', '0.2%', 'No'],
#  ['GPKOW', '2', '2', '499', '0.4%', 'No'],
#  ['HTR5A', '1', '1', '499', '0.2%', 'No'],
#  ['SORL1', '3', '3', '499', '0.6%', 'No'],
#  ['MSMP', '1', '1', '499', '0.2%', 'No'],
#  ['DYTN', '2', '2', '499', '0.4%', 'No'],
#  ['CDKN2AIPNL', '1', '1', '499', '0.2%', 'No'],
#  ['UROC1', '3', '3', '499', '0.6%', 'No'],
#  ['IL2RB', '1', '1', '499', '0.2%', 'No'],
#  ['APLF', '1', '1', '499', '0.2%', 'No'],
#  ['PDCD2', '1', '1', '499', '0.2%', 'No'],
#  ['PDCD1', '1', '1', '499', '0.2%', 'Yes'],
#  ['KCNK1', '1', '1', '499', '0.2%', 'No'],
#  ['KCNK2', '3', '3', '499', '0.6%', 'No'],
#  ['NOP53', '1', '1', '499', '0.2%', 'No'],
#  ['BCAR1', '3', '2', '499', '0.4%', 'No'],
#  ['UNC79', '9', '9', '499', '1.8%', 'No'],
#  ['CDRT15', '1', '1', '499', '0.2%', 'No'],
#  ['SLC23A2', '1', '1', '499', '0.2%', 'No'],
#  ['CERK', '1', '1', '499', '0.2%', 'No'],
#  ['RCBTB2', '1', '1', '499', '0.2%', 'No'],
#  ['STS', '1', '1', '499', '0.2%', 'No'],
#  ['IL36A', '1', '1', '499', '0.2%', 'No'],
#  ['IL36B', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO4', '2', '2', '499', '0.4%', 'No'],
#  ['TNFSF11', '1', '1', '499', '0.2%', 'No'],
#  ['BCRP7', '1', '1', '499', '0.2%', 'No'],
#  ['FBXO6', '2', '2', '499', '0.4%', 'No'],
#  ['FBXO5', '2', '2', '499', '0.4%', 'No'],
#  ['BSN', '11', '10', '499', '2.0%', 'No'],
#  ['ATXN7L2', '1', '1', '499', '0.2%', 'No'],
#  ['ATXN7L3', '1', '1', '499', '0.2%', 'No'],
#  ['LIMCH1', '4', '4', '499', '0.8%', 'No'],
#  ['BSX', '1', '1', '499', '0.2%', 'No'],
#  ['GOLPH3L', '2', '2', '499', '0.4%', 'No'],
#  ['BCS1L', '2', '2', '499', '0.4%', 'No'],
#  ['CFAP141', '1', '1', '499', '0.2%', 'No'],
#  ['BTD', '1', '1', '499', '0.2%', 'No'],
#  ['SNORC', '1', '1', '499', '0.2%', 'No'],
#  ['CRISPLD1', '1', '1', '499', '0.2%', 'No'],
#  ['SOAT2', '3', '3', '499', '0.6%', 'No'],
#  ['KCNQ1', '2', '2', '499', '0.4%', 'No'],
#  ['KCNQ2', '2', '2', '499', '0.4%', 'No'],
#  ['BTK', '1', '1', '499', '0.2%', 'Yes'],
#  ['KCNQ3', '3', '3', '499', '0.6%', 'No'],
#  ['MTCP1', '1', '1', '499', '0.2%', 'Yes'],
#  ['KCNQ5', '2', '2', '499', '0.4%', 'No'],
#  ['CES3', '1', '1', '499', '0.2%', 'No'],
#  ['CES2', '2', '1', '499', '0.2%', 'No'],
#  ['CES1', '3', '3', '499', '0.6%', 'No'],
#  ['CETP', '2', '2', '499', '0.4%', 'No'],
#  ['GRB7', '2', '2', '499', '0.4%', 'Yes'],
#  ['CERKL', '1', '1', '499', '0.2%', 'No'],
#  ['AARS1', '2', '2', '499', '0.4%', 'No'],
#  ['AARS2', '2', '1', '499', '0.2%', 'No'],
#  ['DHX8', '2', '2', '499', '0.4%', 'No'],
#  ['SDC4', '1', '1', '499', '0.2%', 'Yes'],
#  ['DHX9', '1', '1', '499', '0.2%', 'No'],
#  ['RRAD', '1', '1', '499', '0.2%', 'No'],
#  ['SDC3', '1', '1', '499', '0.2%', 'No'],
#  ['MYCBP2', '10', '9', '499', '1.8%', 'No'],
#  ['CWF19L2', '2', '2', '499', '0.4%', 'No'],
#  ['ZBTB5', '1', '1', '499', '0.2%', 'No'],
#  ['ZBTB4', '2', '2', '499', '0.4%', 'No'],
#  ['ZBTB3', '2', '2', '499', '0.4%', 'No'],
#  ['CFAP126', '1', '1', '499', '0.2%', 'No'],
#  ['ZBTB2', '1', '1', '499', '0.2%', 'No'],
#  ['NEU2', '2', '2', '499', '0.4%', 'No'],
#  ['PKHD1', '10', '9', '499', '1.8%', 'No'],
#  ['APOO', '2', '2', '499', '0.4%', 'No'],
#  ['NEU4', '2', '2', '499', '0.4%', 'No'],
#  ['MRNIP', '3', '3', '499', '0.6%', 'No'],
#  ['NKAIN3', '1', '1', '499', '0.2%', 'No'],
#  ['RACGAP1', '1', '1', '499', '0.2%', 'No'],
#  ['NEU1', '1', '1', '499', '0.2%', 'No'],
#  ['KCNN1', '1', '1', '499', '0.2%', 'No'],
#  ['STK38L', '1', '1', '499', '0.2%', 'No'],
#  ['KCNN2', '6', '6', '499', '1.2%', 'No'],
#  ['H3C3', '1', '1', '499', '0.2%', 'Yes'],
#  ['APOE', '2', '2', '499', '0.4%', 'No'],
#  ['KCNN3', '3', '3', '499', '0.6%', 'No'],
#  ['H3C2', '1', '1', '499', '0.2%', 'Yes'],
#  ['APOB', '11', '10', '499', '2.0%', 'No'],
#  ['KCNN4', '1', '1', '499', '0.2%', 'No'],
#  ['H3C7', '1', '1', '499', '0.2%', 'Yes'],
#  ['H3C6', '1', '1', '499', '0.2%', 'Yes'],
#  ['BBS2', '2', '2', '499', '0.4%', 'No'],
#  ['NTNG1', '3', '3', '499', '0.6%', 'No'],
#  ['BBS1', '2', '2', '499', '0.4%', 'No'],
#  ['NTNG2', '1', '1', '499', '0.2%', 'No'],
#  ['SLC10A5', '1', '1', '499', '0.2%', 'No'],
#  ['XBP1', '1', '1', '499', '0.2%', 'Yes'],
#  ['YES1', '1', '1', '499', '0.2%', 'Yes'],
#  ['TNFSF14', '2', '2', '499', '0.4%', 'No'],
#  ['APOBEC3G', '1', '1', '499', '0.2%', 'No'],
#  ['TNFSF15', '1', '1', '499', '0.2%', 'No'],
#  ['SLC10A2', '5', '5', '499', '1.0%', 'No'],
#  ['SPDYC', '2', '2', '499', '0.4%', 'No'],
#  ['SLC10A3', '1', '1', '499', '0.2%', 'No'],
#  ['IGF2', '1', '1', '499', '0.2%', 'Yes'],
#  ['DELE1', '3', '3', '499', '0.6%', 'No'],
#  ['SUCO', '1', '1', '499', '0.2%', 'No'],
#  ['CPLANE1', '3', '1', '499', '0.2%', 'No'],
#  ['NET1', '3', '3', '499', '0.6%', 'No'],
#  ['ZBTB9', '2', '2', '499', '0.4%', 'No'],
#  ['CYP26A1', '1', '1', '499', '0.2%', 'No'],
#  ['FBXL8', '1', '1', '499', '0.2%', 'No'],
#  ['PEX5L', '1', '1', '499', '0.2%', 'No'],
#  ['ZBTB6', '1', '1', '499', '0.2%', 'No'],
#  ['CWF19L1', '4', '3', '499', '0.6%', 'No'],
#  ['OR4D11', '1', '1', '499', '0.2%', 'No'],
#  ['ITGBL1', '3', '3', '499', '0.6%', 'No'],
#  ['OR4D10', '2', '2', '499', '0.4%', 'No'],
#  ['GRB2', '1', '1', '499', '0.2%', 'No'],
#  ['FBXL2', '1', '1', '499', '0.2%', 'No'],
#  ['FBXL4', '1', '1', '499', '0.2%', 'No'],
#  ['FBXL7', '3', '3', '499', '0.6%', 'No'],
#  ['LDHAL6A', '1', '1', '499', '0.2%', 'No'],
#  ['APOBEC3B', '4', '4', '499', '0.8%', 'Yes'],
#  ['FBXL6', '2', '2', '499', '0.4%', 'No'],
#  ['MSTN', '2', '2', '499', '0.4%', 'No'],
#  ['MRPS10', '2', '2', '499', '0.4%', 'No'],
#  ['C8B', '2', '2', '499', '0.4%', 'No'],
#  ['TFB1M', '1', '1', '499', '0.2%', 'No'],
#  ['C8A', '3', '1', '499', '0.2%', 'No'],
#  ['MC4R', '1', '1', '499', '0.2%', 'No'],
#  ['DMBX1', '2', '2', '499', '0.4%', 'No'],
#  ['KCNT1', '4', '4', '499', '0.8%', 'No'],
#  ['KCNT2', '7', '6', '499', '1.2%', 'No'],
#  ['SUFU', '1', '1', '499', '0.2%', 'Yes'],
#  ['RAC2', '1', '1', '499', '0.2%', 'Yes'],
#  ['FCER1A', '1', '1', '499', '0.2%', 'No'],
#  ['RAC3', '2', '2', '499', '0.4%', 'No'],
#  ['BBS9', '5', '5', '499', '1.0%', 'No'],
#  ['SDF4', '1', '1', '499', '0.2%', 'No'],
#  ['RAC1', '1', '1', '499', '0.2%', 'Yes'],
#  ['BBS7', '1', '1', '499', '0.2%', 'No'],
#  ['BBS5', '1', '1', '499', '0.2%', 'No'],
#  ['BBS4', '4', '4', '499', '0.8%', 'No'],
#  ['MRPS28', '1', '1', '499', '0.2%', 'No'],
#  ['H3C8', '3', '3', '499', '0.6%', 'Yes'],
#  ['PCYT1B', '1', '1', '499', '0.2%', 'No'],
#  ['ZHX2', '3', '2', '499', '0.4%', 'No'],
#  ['PCYT1A', '1', '1', '499', '0.2%', 'No'],
#  ['ZHX3', '1', '1', '499', '0.2%', 'No'],
#  ['SYK', '2', '2', '499', '0.4%', 'Yes'],
#  ['MRPS25', '2', '2', '499', '0.4%', 'No'],
#  ['MRPS22', '1', '1', '499', '0.2%', 'No'],
#  ['MST1', '4', '3', '499', '0.6%', 'Yes'],
#  ['MRPS23', '1', '1', '499', '0.2%', 'No'],
#  ['GAB1', '1', '1', '499', '0.2%', 'Yes'],
#  ['PRPF40B', '3', '3', '499', '0.6%', 'No'],
#  ['CACYBP', '1', '1', '499', '0.2%', 'No'],
#  ['GAB2', '5', '5', '499', '1.0%', 'Yes'],
#  ['TFB2M', '3', '3', '499', '0.6%', 'No'],
#  ['ZHX1', '2', '2', '499', '0.4%', 'No'],
#  ['APRT', '1', '1', '499', '0.2%', 'No'],
#  ['RNF144A', '1', '1', '499', '0.2%', 'No'],
#  ['CNKSR2', '1', '1', '499', '0.2%', 'No'],
#  ['MC3R', '2', '2', '499', '0.4%', 'No'],
#  ['CNKSR1', '1', '1', '499', '0.2%', 'No'],
#  ['KCNU1', '4', '3', '499', '0.6%', 'No'],
#  ['RAP2B', '1', '1', '499', '0.2%', 'No'],
#  ['PITPNM1', '2', '1', '499', '0.2%', 'No'],
#  ['PITPNM2', '2', '1', '499', '0.2%', 'No'],
#  ['CNKSR3', '1', '1', '499', '0.2%', 'No'],
#  ['TAX1BP1', '3', '2', '499', '0.4%', 'No'],
#  ['TLCD4', '1', '1', '499', '0.2%', 'No'],
#  ['FAM193B', '1', '1', '499', '0.2%', 'No'],
#  ['FAM193A', '4', '4', '499', '0.8%', 'No'],
#  ['CYLC2', '1', '1', '499', '0.2%', 'No'],
#  ['MICU1', '2', '2', '499', '0.4%', 'No'],
#  ['CYLC1', '1', '1', '499', '0.2%', 'No'],
#  ['DYNC1I2', '1', '1', '499', '0.2%', 'No'],
#  ['SELPLG', '2', '2', '499', '0.4%', 'No'],
#  ['PRICKLE2', '7', '6', '499', '1.2%', 'No'],
#  ['MRPS30', '1', '1', '499', '0.2%', 'No'],
#  ['PRICKLE1', '2', '2', '499', '0.4%', 'No'],
#  ['MSX1', '1', '1', '499', '0.2%', 'No'],
#  ['RAE1', '3', '3', '499', '0.6%', 'No'],
#  ['DYNC1I1', '2', '2', '499', '0.4%', 'No'],
#  ['PEX16', '1', '1', '499', '0.2%', 'No'],
#  ['DYNC1H1', '8', '6', '499', '1.2%', 'No'],
#  ['MAP3K3', '1', '1', '499', '0.2%', 'No'],
#  ['MAP3K1', '5', '3', '499', '0.6%', 'Yes'],
#  ['SORT1', '1', '1', '499', '0.2%', 'No'],
#  ['GAD1', '2', '2', '499', '0.4%', 'No'],
#  ['GAD2', '9', '9', '499', '1.8%', 'No'],
#  ['KLHL2', '3', '3', '499', '0.6%', 'No'],
#  ['KLHL3', '1', '1', '499', '0.2%', 'No'],
#  ['KLHL4', '3', '3', '499', '0.6%', 'No'],
#  ['KCNRG', '1', '1', '499', '0.2%', 'No'],
#  ['PEX12', '1', '1', '499', '0.2%', 'No'],
#  ['CFAP157', '2', '2', '499', '0.4%', 'No'],
#  ['APTX', '1', '1', '499', '0.2%', 'No'],
#  ['KLHL9', '2', '2', '499', '0.4%', 'No'],
#  ['ETAA1', '2', '2', '499', '0.4%', 'Yes'],
#  ['PDCL3', '1', '1', '499', '0.2%', 'No'],
#  ['PDCL2', '1', '1', '499', '0.2%', 'No'],
#  ['TFAP4', '4', '3', '499', '0.6%', 'No'],
#  ['KCNS1', '1', '1', '499', '0.2%', 'No'],
#  ['KLHL5', '1', '1', '499', '0.2%', 'No'],
#  ['FHIP2A', '1', '1', '499', '0.2%', 'No'],
#  ['KCNS2', '1', '1', '499', '0.2%', 'No'],
#  ['FHIP2B', '1', '1', '499', '0.2%', 'No'],
#  ['KLHL6', '2', '2', '499', '0.4%', 'Yes'],
#  ['KCNS3', '1', '1', '499', '0.2%', 'No'],
#  ['KLHL7', '3', '3', '499', '0.6%', 'No'],
#  ['MC5R', '1', '1', '499', '0.2%', 'No'],
#  ['KLHL8', '2', '2', '499', '0.4%', 'No'],
#  ['CFAP161', '1', '1', '499', '0.2%', 'No'],
#  ['TACC3', '3', '2', '499', '0.4%', 'No'],
#  ['CACHD1', '4', '3', '499', '0.6%', 'No'],
#  ['HDGF', '1', '1', '499', '0.2%', 'No'],
#  ['TACC1', '1', '1', '499', '0.2%', 'No'],
#  ['TACC2', '6', '6', '499', '1.2%', 'No'],
#  ['MAMLD1', '1', '1', '499', '0.2%', 'No'],
#  ['ZFP28', '4', '4', '499', '0.8%', 'No'],
#  ['DENND5B', '1', '1', '499', '0.2%', 'No'],
#  ['INPPL1', '1', '1', '499', '0.2%', 'Yes'],
#  ['PLAT', '3', '3', '499', '0.6%', 'No'],
#  ['PLB1', '2', '2', '499', '0.4%', 'No'],
#  ['IGF1R', '4', '4', '499', '0.8%', 'Yes'],
#  ['TXN2', '1', '1', '499', '0.2%', 'No'],
#  ['TGM1', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF81', '1', '1', '499', '0.2%', 'No'],
#  ['DMBT1', '6', '5', '499', '1.0%', 'No'],
#  ['PLAU', '3', '3', '499', '0.6%', 'No'],
#  ['PPIP5K2', '5', '2', '499', '0.4%', 'No'],
#  ['ZNF85', '1', '1', '499', '0.2%', 'No'],
#  ['ENPP2', '4', '4', '499', '0.8%', 'No'],
#  ['ENPP1', '3', '3', '499', '0.6%', 'No'],
#  ['RXYLT1', '2', '2', '499', '0.4%', 'No'],
#  ['ENPP4', '2', '2', '499', '0.4%', 'No'],
#  ['DENND5A', '2', '2', '499', '0.4%', 'No'],
#  ['TGM7', '2', '2', '499', '0.4%', 'No'],
#  ['ENPP3', '2', '2', '499', '0.4%', 'No'],
#  ['TGM6', '5', '5', '499', '1.0%', 'No'],
#  ['TGM5', '2', '2', '499', '0.4%', 'No'],
#  ['ENPP5', '3', '3', '499', '0.6%', 'No'],
#  ['TGM3', '2', '2', '499', '0.4%', 'No'],
#  ['RAG1', '11', '10', '499', '2.0%', 'No'],
#  ['TGM2', '2', '1', '499', '0.2%', 'No'],
#  ['ENPP7', '4', '3', '499', '0.6%', 'No'],
#  ['CARD10', '2', '2', '499', '0.4%', 'No'],
#  ['MSX2', '1', '1', '499', '0.2%', 'No'],
#  ['ZGRF1', '1', '1', '499', '0.2%', 'No'],
#  ['ADAM11', '2', '2', '499', '0.4%', 'No'],
#  ['ADAM10', '2', '2', '499', '0.4%', 'No'],
#  ['ZNF98', '2', '2', '499', '0.4%', 'No'],
#  ['DNAJB13', '1', '1', '499', '0.2%', 'No'],
#  ['SDHC', '2', '2', '499', '0.4%', 'Yes'],
#  ['ZNF99', '10', '10', '499', '2.0%', 'No'],
#  ['DNAJB14', '1', '1', '499', '0.2%', 'No'],
#  ['SDHA', '3', '2', '499', '0.4%', 'Yes'],
#  ['SDHB', '2', '2', '499', '0.4%', 'Yes'],
#  ['ADAM19', '2', '2', '499', '0.4%', 'No'],
#  ['ADAM18', '3', '3', '499', '0.6%', 'No'],
#  ['ZNF91', '12', '12', '499', '2.4%', 'No'],
#  ['BRMS1', '1', '1', '499', '0.2%', 'No'],
#  ['ZNF92', '1', '1', '499', '0.2%', 'No'],
#  ['ADAM15', '3', '2', '499', '0.4%', 'No'],
#  ['ZNF93', '2', '2', '499', '0.4%', 'No'],
#  ['PSPC1', '2', '2', '499', '0.4%', 'No'],
#  ['CARD19', '1', '1', '499', '0.2%', 'No'],
#  ['ADAM12', '3', '3', '499', '0.6%', 'No'],
#  ['DNAJB11', '1', '1', '499', '0.2%', 'No'],
#  ['PLAA', '6', '5', '499', '1.0%', 'No'],
#  ['CARD18', '1', '1', '499', '0.2%', 'No'],
#  ['CARD16', '2', '2', '499', '0.4%', 'No'],
#  ['DENND6A', '1', '1', '499', '0.2%', 'No'],
#  ['RAF1', '1', '1', '499', '0.2%', 'Yes'],
#  ['CARD14', '2', '2', '499', '0.4%', 'No'],
#  ['CARD11', '5', '3', '499', '0.6%', 'Yes'],
#  ['OR1A2', '1', '1', '499', '0.2%', 'No'],
#  ['DIPK1B', '1', '1', '499', '0.2%', 'No'],
#  ['HTRA4', '2', '2', '499', '0.4%', 'No'],
#  ['HTRA1', '1', '1', '499', '0.2%', 'No'],
#  ['PLD5', '1', '1', '499', '0.2%', 'No'],
#  ['DAPP1', '1', '1', '499', '0.2%', 'No'],
#  ['HTRA2', '1', '1', '499', '0.2%', 'No'],
#  ['PLD4', '1', '1', '499', '0.2%', 'No'],
#  ['PLD1', '3', '3', '499', '0.6%', 'No'],
#  ['PLD2', '2', '2', '499', '0.4%', 'No'],
#  ['GRK1', '2', '2', '499', '0.4%', 'No'],
#  ['RAI1', '5', '5', '499', '1.0%', 'No'],
#  ['KCNV1', '5', '5', '499', '1.0%', 'No'],
#  ['KCNV2', '2', '1', '499', '0.2%', 'No'],
#  ['GRK4', '1', '1', '499', '0.2%', 'No'],
#  ['GRK7', '1', '1', '499', '0.2%', 'No'],
#  ['GRK6', '3', '3', '499', '0.6%', 'No'],
#  ['FGF20', '1', '1', '499', '0.2%', 'No'],
#  ['IL36RN', '2', '2', '499', '0.4%', 'No'],
#  ['FGF23', '2', '2', '499', '0.4%', 'Yes'],
#  ['PIBF1', '1', '1', '499', '0.2%', 'No'],
#  ['FGF21', '1', '1', '499', '0.2%', 'No'],
#  ['SPATA31A6', '10', '9', '499', '1.8%', 'No'],
#  ['SPATA31A7', '2', '2', '499', '0.4%', 'No'],
#  ['DENND4B', '2', '2', '499', '0.4%', 'No'],
#  ['DENND4A', '4', '3', '499', '0.6%', 'No'],
#  ['DENND4C', '1', '1', '499', '0.2%', 'No'],
#  ['FAM199X', '1', '1', '499', '0.2%', 'No'],
#  ['IGF2R', '3', '3', '499', '0.6%', 'No'],
#  ['FGF16', '2', '2', '499', '0.4%', 'No'],
#  ['SDK1', '7', '6', '499', '1.2%', 'No'],
#  ['IFT27', '1', '1', '499', '0.2%', 'No'],
#  ['FGF11', '1', '1', '499', '0.2%', 'No'],
#  ['SDK2', '5', '3', '499', '0.6%', 'No'],
#  ['FGF10', '2', '2', '499', '0.4%', 'Yes'],
#  ['ZMYND15', '3', '3', '499', '0.6%', 'No'],
#  ['ZMYND19', '1', '1', '499', '0.2%', 'No'],
#  ['MYSM1', '1', '1', '499', '0.2%', 'No'],
#  ['GRM1', '11', '11', '499', '2.2%', 'No'],
#  ['PITPNC1', '2', '2', '499', '0.4%', 'No'],
#  ['GRM3', '4', '4', '499', '0.8%', 'Yes'],
#  ['GRM2', '3', '2', '499', '0.4%', 'No'],
#  ['CA1', '1', '1', '499', '0.2%', 'No'],
#  ['GRM5', '4', '3', '499', '0.6%', 'No'],
#  ['LASP1', '2', '2', '499', '0.4%', 'Yes'],
#  ['CYP26B1', '1', '1', '499', '0.2%', 'No'],
#  ['GRM4', '2', '2', '499', '0.4%', 'No'],
#  ['EEF2K', '5', '5', '499', '1.0%', 'No'],
#  ['CA3', '1', '1', '499', '0.2%', 'No'],
#  ['GRM7', '3', '3', '499', '0.6%', 'No'],
#  ['ZIC2', '2', '2', '499', '0.4%', 'No'],
#  ['CA2', '3', '3', '499', '0.6%', 'No'],
#  ['GRM6', '3', '2', '499', '0.4%', 'No'],
#  ['ZIC3', '2', '2', '499', '0.4%', 'No'],
#  ['CA4', '2', '2', '499', '0.4%', 'No'],
#  ['GRM8', '2', '2', '499', '0.4%', 'No'],
#  ['ZIC1', '3', '3', '499', '0.6%', 'No'],
#  ['CA6', '1', '1', '499', '0.2%', 'No'],
#  ['CA9', '2', '2', '499', '0.4%', 'No'],
#  ['MYBL2', '3', '2', '499', '0.4%', 'No'],
#  ['CA8', '4', '4', '499', '0.8%', 'No'],
#  ['MYBL1', '2', '2', '499', '0.4%', 'Yes'],
#  ['IFT56', '2', '2', '499', '0.4%', 'No'],
#  ['SUN2', '3', '3', '499', '0.6%', 'No'],
#  ['CAD', '9', '4', '499', '0.8%', 'Yes'],
#  ['ATP6AP2', '1', '1', '499', '0.2%', 'No'],
#  ['HUNK', '1', '1', '499', '0.2%', 'No'],
#  ['EEF1G', '1', '1', '499', '0.2%', 'No'],
#  ['ELF1', '1', '1', '499', '0.2%', 'No'],
#  ['CFAP100', '1', '1', '499', '0.2%', 'No'],
#  ['ELF2', '1', '1', '499', '0.2%', 'No'],
#  ['IFT43', '1', '1', '499', '0.2%', 'No'],
#  ['GFOD1', '1', '1', '499', '0.2%', 'No'],
#  ['EEF1D', '1', '1', '499', '0.2%', 'No'],
#  ['ELF4', '1', '1', '499', '0.2%', 'Yes'],
#  ['CAT', '2', '2', '499', '0.4%', 'No'],
#  ['GFOD2', '1', '1', '499', '0.2%', 'No'],
#  ['SPATA31D1', '4', '4', '499', '0.8%', 'No'],
#  ['ZMYND11', '1', '1', '499', '0.2%', 'No'],
#  ['IFT46', '1', '1', '499', '0.2%', 'No'],
#  ['ZMYND12', '4', '4', '499', '0.8%', 'No'],
#  ['SHANK3', '2', '2', '499', '0.4%', 'No'],
#  ['SHANK2', '8', '5', '499', '1.0%', 'No'],
#  ['PLEC', '9', '6', '499', '1.2%', 'No'],
#  ['SHANK1', '3', '3', '499', '0.6%', 'No'],
#  ['PSMB11', '2', '2', '499', '0.4%', 'No'],
#  ['GALT', '1', '1', '499', '0.2%', 'No'],
#  ['TAFAZZIN', '1', '1', '499', '0.2%', 'No'],
#  ['CBL', '1', '1', '499', '0.2%', 'Yes'],
#  ['IL1RL1', '1', '1', '499', '0.2%', 'No'],
#  ['IFT74', '1', '1', '499', '0.2%', 'No'],
#  ['IL1RL2', '2', '2', '499', '0.4%', 'No'],
#  ['NWD1', '6', '6', '499', '1.2%', 'No'],
#  ['MTA1', '2', '2', '499', '0.4%', 'No'],
#  ['SV2B', '2', '2', '499', '0.4%', 'No'],
#  ['CBS', '1', '1', '499', '0.2%', 'No'],
#  ['OXCT1', '5', '2', '499', '0.4%', 'No'],
#  ['SV2A', '3', '3', '499', '0.6%', 'No'],
#  ['TDG', '1', '1', '499', '0.2%', 'No'],
#  ['TBX20', '3', '3', '499', '0.6%', 'No'],
#  ['MVB12B', '1', '1', '499', '0.2%', 'No'],
#  ['SLIT1', '2', '2', '499', '0.4%', 'No'],
#  ['CLVS2', '1', '1', '499', '0.2%', 'No'],
#  ['DROSHA', '3', '3', '499', '0.6%', 'Yes'],
#  ['SLIT3', '4', '4', '499', '0.8%', 'Yes'],
#  ['RALY', '1', '1', '499', '0.2%', 'No'],
#  ['SLIT2', '3', '2', '499', '0.4%', 'Yes'],
#  ['MTA2', '1', '1', '499', '0.2%', 'No'],
#  ['SPATA31E1', '2', '2', '499', '0.4%', 'No'],
#  ['CLVS1', '2', '2', '499', '0.4%', 'No'],
#  ['OR1D5', '1', '1', '499', '0.2%', 'No'],
#  ['OR1D2', '1', '1', '499', '0.2%', 'No'],
#  ['RRM2', '1', '1', '499', '0.2%', 'No'],
#  ['HSD3B2', '2', '2', '499', '0.4%', 'No'],
#  ['HSD3B1', '2', '2', '499', '0.4%', 'Yes'],
#  ['ZIC4', '3', '3', '499', '0.6%', 'No'],
#  ['HS3ST6', '1', '1', '499', '0.2%', 'No'],
#  ['ZIC5', '3', '3', '499', '0.6%', 'No'],
#  ['SUOX', '1', '1', '499', '0.2%', 'No'],
#  ['TBX19', '2', '2', '499', '0.4%', 'No'],
#  ['WARS1', '1', '1', '499', '0.2%', 'No'],
#  ['TBX18', '4', '4', '499', '0.8%', 'No'],
#  ['WARS2', '2', '2', '499', '0.4%', 'No'],
#  ['CD2', '1', '1', '499', '0.2%', 'No'],
#  ['GALC', '1', '1', '499', '0.2%', 'No'],
#  ['TBX15', '2', '2', '499', '0.4%', 'No'],
#  ['CD4', '1', '1', '499', '0.2%', 'No'],
#  ['GALE', '1', '1', '499', '0.2%', 'No'],
#  ['TEC', '1', '1', '499', '0.2%', 'Yes'],
#  ['CD6', '1', '1', '499', '0.2%', 'No'],
#  ['TNIP1', '3', '3', '499', '0.6%', 'No'],
#  ['TNIP2', '1', '1', '499', '0.2%', 'No'],
#  ['TNIP3', '1', '1', '499', '0.2%', 'No'],
#  ['TBX10', '1', '1', '499', '0.2%', 'No'],
#  ['CD9', '1', '1', '499', '0.2%', 'No'],
#  ['TEK', '2', '2', '499', '0.4%', 'Yes'],
#  ['IPO13', '1', '1', '499', '0.2%', 'No'],
#  ['VPS29', '1', '1', '499', '0.2%', 'No'],
#  ['IPO11', '1', '1', '499', '0.2%', 'No'],
#  ['FRMPD3', '2', '1', '499', '0.2%', 'No'],
#  ['FRMPD4', '1', '1', '499', '0.2%', 'No'],
#  ['FRMPD1', '5', '4', '499', '0.8%', 'No'],
#  ['RRP1', '1', '1', '499', '0.2%', 'No'],
#  ['FRMPD2', '2', '2', '499', '0.4%', 'No'],
#  ['CWH43', '2', '2', '499', '0.4%', 'No'],
#  ['MSANTD4', '2', '2', '499', '0.4%', 'No'],
#  ['SLCO6A1', '3', '3', '499', '0.6%', 'No'],
#  ['GRPR', '1', '1', '499', '0.2%', 'No'],
#  ['CAPN15', '3', '3', '499', '0.6%', 'No'],
#  ['RRP9', '1', '1', '499', '0.2%', 'No'],
#  ['MTBP', '3', '2', '499', '0.4%', 'No'],
#  ['ALCAM', '2', '2', '499', '0.4%', 'No'],
#  ['TFG', '1', '1', '499', '0.2%', 'Yes'],
#  ['ZSCAN31', '1', '1', '499', '0.2%', 'No'],
#  ['SCN11A', '8', '8', '499', '1.6%', 'No'],
#  ['IGKV1-17', '1', '1', '499', '0.2%', 'No'],
#  ['ZSCAN30', '2', '2', '499', '0.4%', 'No'],
#  ['VPS35', '2', '2', '499', '0.4%', 'No'],
#  ['VPS39', '1', '1', '499', '0.2%', 'No'],
#  ['PRKCG', '1', '1', '499', '0.2%', 'No'],
#  ['VPS18', '1', '1', '499', '0.2%', 'No'],
#  ['PRKCI', '1', '1', '499', '0.2%', 'Yes'],
#  ['PRKCH', '1', '1', '499', '0.2%', 'No'],
#  ['TAAR8', '3', '3', '499', '0.6%', 'No'],
#  ['PRKCB', '2', '2', '499', '0.4%', 'No'],
#  ['TAAR9', '1', '1', '499', '0.2%', 'No'],
#  ['PRKCE', '2', '1', '499', '0.2%', 'No'],
#  ['DNAAF1', '5', '2', '499', '0.4%', 'No'],
#  ['TAAR6', '3', '3', '499', '0.6%', 'No'],
#  ['HUS1', '1', '1', '499', '0.2%', 'No'],
#  ['TAAR5', '1', '1', '499', '0.2%', 'No'],
#  ['AFAP1', '5', '4', '499', '0.8%', 'No'],
#  ['PRKCA', '2', '2', '499', '0.4%', 'No'],
#  ['TAAR2', '1', '1', '499', '0.2%', 'No'],
#  ['DNAAF5', '2', '2', '499', '0.4%', 'No'],
#  ['DNAAF4', '1', '1', '499', '0.2%', 'No'],
#  ['GANC', '3', '2', '499', '0.4%', 'No'],
#  ['DNAAF9', '4', '4', '499', '0.8%', 'No'],
#  ['DNAAF8', '1', '1', '499', '0.2%', 'No'],
#  ['BCAN', '5', '3', '499', '0.6%', 'No'],
#  ['BCAM', '3', '3', '499', '0.6%', 'No'],
#  ['MTAP', '1', '1', '499', '0.2%', 'Yes'],
#  ['SCN10A', '8', '8', '499', '1.6%', 'No'],
#  ['DAAM1', '4', '3', '499', '0.6%', 'No'],
#  ['IGKV1-27', '1', '1', '499', '0.2%', 'No'],
#  ['DAAM2', '4', '4', '499', '0.8%', 'No'],
#  ['PRKD3', '1', '1', '499', '0.2%', 'No'],
#  ['HECW2', '1', '1', '499', '0.2%', 'No'],
#  ['ZSCAN22', '1', '1', '499', '0.2%', 'No'],
#  ['KRTAP4-11', '25', '24', '499', '4.8%', 'No'],
#  ['ZSCAN21', '2', '2', '499', '0.4%', 'No'],
#  ['HECW1', '2', '2', '499', '0.4%', 'No'],
#  ['ZSCAN23', '1', '1', '499', '0.2%', 'No'],
#  ['PRKCQ', '3', '2', '499', '0.4%', 'No'],
#  ['PRKD2', '1', '1', '499', '0.2%', 'No'],
#  ['TARS2', '3', '3', '499', '0.6%', 'No'],
#  ['SRFBP1', '3', '3', '499', '0.6%', 'No'],
#  ['NUP98', '4', '4', '499', '0.8%', 'Yes'],
#  ['PRKD1', '2', '2', '499', '0.4%', 'Yes'],
#  ['TARS3', '1', '1', '499', '0.2%', 'No'],
#  ['ZSCAN25', '2', '2', '499', '0.4%', 'No'],
#  ['TARS1', '4', '4', '499', '0.8%', 'No'],
#  ['FREM1', '4', '4', '499', '0.8%', 'No'],
#  ['CFB', '3', '2', '499', '0.4%', 'No'],
#  ['VPS28', '1', '1', '499', '0.2%', 'No'],
#  ['FREM2', '13', '9', '499', '1.8%', 'No'],
#  ['ZSCAN29', '1', '1', '499', '0.2%', 'No'],
#  ['CFD', '1', '1', '499', '0.2%', 'No'],
#  ['CFH', '9', '8', '499', '1.6%', 'No'],
#  ['PRKDC', '11', '10', '499', '2.0%', 'Yes'],
#  ['CFI', '1', '1', '499', '0.2%', 'No'],
#  ['PRDM15', '1', '1', '499', '0.2%', 'No'],
#  ['METTL25B', '1', '1', '499', '0.2%', 'No'],
#  ['PRDM14', '2', '2', '499', '0.4%', 'Yes'],
#  ['PRDM12', '2', '2', '499', '0.4%', 'No'],
#  ['SDSL', '1', '1', '499', '0.2%', 'No'],
#  ['PRKCZ', '3', '3', '499', '0.6%', 'No'],
#  ['PRDM10', '1', '1', '499', '0.2%', 'No'],
#  ['MTDH', '2', '2', '499', '0.4%', 'No'],
#  ['RRP7A', '1', '1', '499', '0.2%', 'No'],
#  ['NUP85', '3', '3', '499', '0.6%', 'No'],
#  ['PRDM16', '3', '3', '499', '0.6%', 'Yes'],
#  ['ZSCAN10', '5', '5', '499', '1.0%', 'No'],
#  ['GAR1', '1', '1', '499', '0.2%', 'No'],
#  ['VPS11', '2', '2', '499', '0.4%', 'No'],
#  ['NUP88', '1', '1', '499', '0.2%', 'No'],
#  ['ST3GAL6', '1', '1', '499', '0.2%', 'No'],
#  ['CGA', '1', '1', '499', '0.2%', 'No'],
#  ['ST3GAL1', '2', '2', '499', '0.4%', 'No'],
#  ['ZSCAN16', '1', '1', '499', '0.2%', 'No'],
#  ['ST3GAL3', '1', '1', '499', '0.2%', 'No'],
#  ['VPS16', '2', '2', '499', '0.4%', 'No'],
#  ['FAM120AOS', '1', '1', '499', '0.2%', 'No'],
#  ['PLK4', '3', '2', '499', '0.4%', 'No'],
#  ['LRRC37A3', '1', '1', '499', '0.2%', 'No'],
#  ['PLK3', '3', '3', '499', '0.6%', 'No'],
#  ['LRRC37A2', '1', '1', '499', '0.2%', 'No'],
#  ['HOMER1', '1', '1', '499', '0.2%', 'No'],
#  ['MCAM', '1', '1', '499', '0.2%', 'No'],
#  ['PLK1', '1', '1', '499', '0.2%', 'No'],
#  ['CGN', '4', '3', '499', '0.6%', 'No'],
#  ['PEDS1-UBE2V1', '1', '1', '499', '0.2%', 'No'],
#  ['MEX3B', '1', '1', '499', '0.2%', 'No'],
#  ['MEX3A', '1', '1', '499', '0.2%', 'No'],
#  ['SETD4', '1', '1', '499', '0.2%', 'Yes'],
#  ['BTG4', '1', '1', '499', '0.2%', 'No'],
#  ['DENND1C', '1', '1', '499', '0.2%', 'No'],
#  ['BTG3', '2', '2', '499', '0.4%', 'No'],
#  ['SETD5', '7', '3', '499', '0.6%', 'Yes'],
#  ['DENND1B', '1', '1', '499', '0.2%', 'No'],
#  ['CDKN1A', '2', '2', '499', '0.4%', 'Yes'],
#  ['RARG', '1', '1', '499', '0.2%', 'No'],
#  ['SETD2', '10', '10', '499', '2.0%', 'Yes'],
#  ['BTG1', '1', '1', '499', '0.2%', 'Yes'],
#  ['CDKN1B', '6', '6', '499', '1.2%', 'Yes'],
#  ['SETD3', '1', '1', '499', '0.2%', 'Yes'],
#  ['DENND1A', '3', '2', '499', '0.4%', 'No'],
#  ['SETD6', '1', '1', '499', '0.2%', 'Yes'],
#  ['SETD7', '1', '1', '499', '0.2%', 'Yes'],
#  ['STON1', '1', '1', '499', '0.2%', 'No'],
#  ['CHM', '3', '3', '499', '0.6%', 'No'],
#  ['ASH2L', '1', '1', '499', '0.2%', 'No'],
#  ['STON2', '2', '1', '499', '0.2%', 'No'],
#  ['ASGR1', '1', '1', '499', '0.2%', 'No'],
#  ['ASGR2', '1', '1', '499', '0.2%', 'No'],
#  ['ADAMTSL1', '5', '5', '499', '1.0%', 'No'],
#  ['ADAMTSL5', '1', '1', '499', '0.2%', 'No'],
#  ['ADAMTSL4', '1', '1', '499', '0.2%', 'No'],
#  ['MTG1', '1', '1', '499', '0.2%', 'No'],
#  ['MTG2', '2', '2', '499', '0.4%', 'No'],
#  ['ADAMTSL3', '2', '2', '499', '0.4%', 'No'],
#  ['DENND11', '1', '1', '499', '0.2%', 'No'],
#  ['ADAMTSL2', '1', '1', '499', '0.2%', 'No'],
#  ['DENND10', '1', '1', '499', '0.2%', 'No'],
#  ['ELOA', '5', '5', '499', '1.0%', 'No'],
#  ['GAST', '1', '1', '499', '0.2%', 'No'],
#  ['ELOB', '1', '1', '499', '0.2%', 'No'],
#  ['RRP12', '4', '4', '499', '0.8%', 'No'],
#  ['CIC', '1', '1', '499', '0.2%', 'Yes'],
#  ['DENND2C', '1', '1', '499', '0.2%', 'No'],
#  ['EXOC7', '1', '1', '499', '0.2%', 'No'],
#  ['PLLP', '1', '1', '499', '0.2%', 'No'],
#  ['ZSCAN5B', '1', '1', '499', '0.2%', 'No'],
#  ['DENND2B', '3', '3', '499', '0.6%', 'No'],
#  ['DENND2A', '2', '2', '499', '0.4%', 'No'],
#  ['COPZ2', '1', '1', '499', '0.2%', 'No'],
#  ['ASH1L', '8', '8', '499', '1.6%', 'No'],
#  ['CIT', '3', '3', '499', '0.6%', 'No'],
#  ['ANGPTL7', '1', '1', '499', '0.2%', 'No'],
#  ['ANGPTL6', '2', '2', '499', '0.4%', 'No'],
#  ['MTF1', '5', '4', '499', '0.8%', 'No'],
#  ['RARA', '1', '1', '499', '0.2%', 'Yes'],
#  ['EXOC4', '2', '2', '499', '0.4%', 'No'],
#  ['PLIN4', '2', '2', '499', '0.4%', 'No'],
#  ['RARB', '3', '3', '499', '0.6%', 'No'],
#  ['PLIN3', '3', '3', '499', '0.6%', 'No'],
#  ['EXOC3', '4', '1', '499', '0.2%', 'No'],
#  ['ANGPTL2', '1', '1', '499', '0.2%', 'No'],
#  ['PLIN2', '1', '1', '499', '0.2%', 'No'],
#  ['EXOC6', '1', '1', '499', '0.2%', 'No'],
#  ['ANGPTL5', '1', '1', '499', '0.2%', 'No'],
#  ['PLIN1', '1', '1', '499', '0.2%', 'No'],
#  ['SINHCAF', '1', '1', '499', '0.2%', 'No'],
#  ['TKT', '2', '2', '499', '0.4%', 'No'],
#  ['RCCD1', '1', '1', '499', '0.2%', 'No'],
#  ['GART', '1', '1', '499', '0.2%', 'No'],
#  ['MOCS1', '2', '2', '499', '0.4%', 'No'],
#  ['GAS8', '2', '2', '499', '0.4%', 'No'],
#  ['EXOC2', '4', '4', '499', '0.8%', 'No'],
#  ['GAS7', '2', '2', '499', '0.4%', 'Yes'],
#  ['EXOC1', '4', '4', '499', '0.8%', 'No'],
#  ['PLIN5', '1', '1', '499', '0.2%', 'No'],
#  ['NFIX', '1', '1', '499', '0.2%', 'No'],
#  ['DCAF12L2', '2', '2', '499', '0.4%', 'No'],
#  ['DCAF12L1', '3', '3', '499', '0.6%', 'No'],
#  ['PRUNE2', '3', '1', '499', '0.2%', 'No'],
#  ['PAPSS2', '1', '1', '499', '0.2%', 'No'],
#  ['APOL4', '1', '1', '499', '0.2%', 'No'],
#  ['METTL21C', '1', '1', '499', '0.2%', 'No'],
#  ['ERMP1', '1', '1', '499', '0.2%', 'No'],
#  ['APOL6', '1', '1', '499', '0.2%', 'No'],
#  ['OLFML3', '1', '1', '499', '0.2%', 'No'],
#  ['ARRDC1-AS1', '1', '1', '499', '0.2%', 'No'],
#  ['RRP36', '5', '5', '499', '1.0%', 'No'],
#  ['CKB', '1', '1', '499', '0.2%', 'No'],
#  ['APOL1', '1', '1', '499', '0.2%', 'No'],
#  ['PAIP2', '1', '1', '499', '0.2%', 'No'],
#  ['MBNL3', '1', '1', '499', '0.2%', 'No'],
#  ['ZIM2', '2', '2', '499', '0.4%', 'No'],
#  ['APOL2', '1', '1', '499', '0.2%', 'No'],
#  ['ZIM3', '1', '1', '499', '0.2%', 'No'],
#  ['BCHE', '3', '3', '499', '0.6%', 'No'],
#  ['HIPK4', '1', '1', '499', '0.2%', 'No'],
#  ['CDKN2A', '1', '1', '499', '0.2%', 'Yes'],
#  ['IL10RA', '2', '2', '499', '0.4%', 'No'],
#  ['MOCOS', '2', '2', '499', '0.4%', 'No'],
#  ['ELP1', '2', '2', '499', '0.4%', 'No'],
#  ['GATC', '1', '1', '499', '0.2%', 'No'],
#  ['GATB', '1', '1', '499', '0.2%', 'No'],
#  ['ELP2', '2', '2', '499', '0.4%', 'Yes'],
#  ['ELP3', '1', '1', '499', '0.2%', 'No'],
#  ['SNCAIP', '4', '4', '499', '0.8%', 'Yes'],
#  ['ELP5', '1', '1', '499', '0.2%', 'No'],
#  ['HIPK1', '4', '3', '499', '0.6%', 'No'],
#  ['HIPK3', '1', '1', '499', '0.2%', 'No'],
#  ...]

# %%
mutated_genes_df = pd.DataFrame(processed_lines[1: ], columns = processed_lines[0])

# %%
mutated_genes_df.head()
# Out:
#       Gene MutSig(Q-value) # Mut #Profiled Samples  Freq  \
# 0  PGLYRP3               1     1               499  0.2%
# 1  PGLYRP2               3     3               499  0.6%
# 2     TFRC               1     1               499  0.2%
# 3     HTR4               1     1               499  0.2%
# 4   PTPDC1               1     1               499  0.2%
#
#   Is Cancer Gene (source: OncoKB)
# 0                              No
# 1                              No
# 2                             Yes
# 3                              No
# 4                              No

# %%
len(processed_lines[1: ])
# Out:
# 11290

# %%
mutated_genes_df.shape
# Out:
# (11290, 6)

# %%
#Saving it as a .csv file
mutated_genes_df.to_csv('Mutated_Genes.csv', index = False)

# %%
mutated_genes_df
# Out:
#           Gene MutSig(Q-value) # Mut #Profiled Samples  Freq  \
# 0      PGLYRP3               1     1               499  0.2%
# 1      PGLYRP2               3     3               499  0.6%
# 2         TFRC               1     1               499  0.2%
# 3         HTR4               1     1               499  0.2%
# 4       PTPDC1               1     1               499  0.2%
# ...        ...             ...   ...               ...   ...
# 11285    SPRY3               1     1               499  0.2%
# 11286    ARB2A               1     1               499  0.2%
# 11287    ABCE1               1     1               499  0.2%
# 11288     HCN2               1     1               499  0.2%
# 11289     HCN1               6     6               499  1.2%
#
#       Is Cancer Gene (source: OncoKB)
# 0                                  No
# 1                                  No
# 2                                 Yes
# 3                                  No
# 4                                  No
# ...                               ...
# 11285                              No
# 11286                              No
# 11287                              No
# 11288                              No
# 11289                              No
#
# [11290 rows x 6 columns]

# %%
processed_gleason_df = pd.read_csv(r'/home/sanven0212/PycharmProjects/MultiOmicsFYP/Balanced_Gleason_Score_Dataset.csv')
processed_gleason_df.head()
# Out:
#     GE_SPOP  GE_FOXA1  GE_CTNNB1  GE_CLPTM1L  GE_DPYSL2  GE_NEIL1  GE_PITPNM2  \
# 0  0.575079  0.587133   0.922717    0.234906   0.748240  0.472291    0.554445
# 1  0.537323  0.651585   0.854902    0.292120   0.490203  0.545553    0.473597
# 2  0.386981  0.582482   0.625047    0.629923   0.651290  0.848843    0.370622
# 3  0.227620  0.672938   0.530553    0.381428   0.175972  0.824114    0.690394
# 4  0.391386  0.539218   0.905188    0.375629   0.809590  0.510654    0.483783
#
#      GE_ATM   GE_EMG1   GE_ETV3  ...  DM_NEIL1  DM_SLC27A4  DM_PITPNM2  \
# 0  0.800431  0.209846  0.968074  ...  0.211153    0.510356    0.759293
# 1  0.775988  0.363620  0.821883  ...  0.308363    1.000000    0.814994
# 2  0.543530  0.454566  0.398550  ...  0.068059    0.287613    0.503656
# 3  0.603873  0.581930  0.815111  ...  0.007223    0.288589    0.872192
# 4  0.744336  0.323944  0.919157  ...  0.300174    0.267242    0.539900
#
#     DM_PTEN   DM_EMG1   DM_ETV3   DM_BRAF  DM_NKX3-1  DM_SALL1  TUMOR_STAGE
# 0  0.071506  0.387823  0.931180  0.163421   0.385668  0.866652            0
# 1  0.033682  0.302847  0.922685  0.165114   0.386124  0.915704            0
# 2  0.042003  0.446778  0.961520  0.322456   0.674538  0.912000            1
# 3  0.069334  0.125432  0.929922  0.232844   0.000000  0.942248            0
# 4  0.127723  0.409610  0.925696  0.192795   0.520819  0.866199            0
#
# [5 rows x 47 columns]

# %%
mutated_genes_df[mutated_genes_df['Gene'] == 'SPOP']
# Out:
#       Gene MutSig(Q-value) # Mut #Profiled Samples   Freq  \
# 8410  SPOP              58    57               499  11.4%
#
#      Is Cancer Gene (source: OncoKB)
# 8410                             Yes

# %% [markdown]
# **Getting the data for the actively mutating genes from mutated genes dataset**

# %%
active_mut_ge = [cols for cols in processed_gleason_df.columns if cols.startswith('GE')]
active_mut_ge
#actively_mutating_genes_df = mutated_genes_df[mutated_genes_df['Gene'] == ]
# Out:
# ['GE_SPOP',
#  'GE_FOXA1',
#  'GE_CTNNB1',
#  'GE_CLPTM1L',
#  'GE_DPYSL2',
#  'GE_NEIL1',
#  'GE_PITPNM2',
#  'GE_ATM',
#  'GE_EMG1',
#  'GE_ETV3',
#  'GE_BRAF',
#  'GE_NKX3-1',
#  'GE_ZMYM3',
#  'GE_SALL1']

# %%
active_mut_values_list = []
for i in active_mut_ge:
